# %%
# 출력이 너무 길어지지 않게하기 위해 찍지 않도록 했으나 
# 실제 학습 할 때는 아래 두 줄을 주석처리 하는 것을 권장한다.
#s
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# pandas 에서 데이터 뽑고, 말뭉치를 뽑아보면 통으로 분석 못 하니까 형태소로 나누는데 나눈 거 중에
#의미 있는 게 서술어, 나 콜라 먹었다.
#뽑아 내는 거 - wordcloud, konlpy
# Out:
# 1.1.1
# 1.18.5

# %%
# pandas 설정: 모든 row와 모든 column을 출력하게 하고, 각 column 별 출력되는 글자수는 50자 이내 글자수를 50개로 두고, head tail
pd.set_option('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', 50)

# %%
# 위의 설정으로 간단하게 보는 df_specific
df_specific = pd.read_csv("/Users/jupiter/Desktop/Exchange_proj/df_specific_wrangle.csv", encoding="utf-8")
df_specific.head(3)
# Out:
#        대학코드                             대학명  \
# 0  AR000004        Universidad del Salvador
# 1  AU000019  Australian National University
# 2  AU000001                 Bond University
#
#                                             gen_info  \
# 0  아르헨티나의 대다수 대학교는 한국처럼 캠퍼스가 있는 것이 아니라 도시 내에 몇개의 ...
# 1  ANU has a very big campus, but unlike Yonsei, ...
# 2  Bond대학교는 휴양지로 유명한 골드코스트에 위치해있습니다. 서퍼스 파라다이스, 브...
#
#                                             env_info  \
# 0  대학교가 도시 여러곳에 분포하고 있으므로 각기 다르다. 하지만 남녀를 불문하고 부에...
# 1  The city center, called CIVIC, is 20min walk a...
# 2  학교 주변은 조용하고 깨끗한 평화로운 전원마을의 느낌입니다. 학교에서 5분정도 걸어...
#
#                                            food_info  \
# 0  기숙사는 학교에서 제공하지 않고 두가지 옵션이 주어진다. 홈스테이 혹은 게스트 하우...
# 1  There are many housing options, but I chose to...
# 2  거주형태는 크게 On Campus와 Off Campus로 나뉩니다. 저는 기숙사에 ...
#
#                                           study_info  \
# 0  아르헨티나에서의 대학 수업은 주로 오전 혹은 저녁에 있다. 대부분의 학생들이 일을하...
# 1  In my personal opinions, classes are generally...
# 2  수업은 보통 4개의 수업을 듣습니다. 저는 Chinese1, Australian p...
#
#                                          office_info  \
# 0  EL SALVADOR대학교는 국제 교육부가 잘 되있는 학교이다. 아르헨티나 대학교들...
# 1  Overall, I did not have to ask for help much f...
# 2  교환생활 중 국제교육부와 연락할 일은 없었습니다. 교환학생을 가서 따로 국제교육부와...
#
#                                           facil_info  \
# 0  부대시설로는 헬스장이 있다고 알고 있으나 시내와 먼 곳에 있었다. 동아리는 몇가지 ...
# 1  There were many clubs for you to join at ANU, ...
# 2  학기초에 동아리 박람회식으로 여러 동아리들의 부스가 세워집니다. 관심 있는 동아리에...
#
#                                            mhct_info  \
# 0  딱히 컬쳐쇼크를 받을 만 한 요소는 없었던 것 같다. 하지만 처음에 언어적인 면에서...
# 1  I did have some culture shock during my first ...
# 2  특별히 culture shock이라기 보다는 정말 다양한 문화를 접하는 것 자체가 ...
#
#                                            help_info  \
# 0  살바도르 대학교 국제처에서 비자문제나 숙소문제(홈스테이경우) 등은 해결해 주고, 특...
# 1  I was helped a lot, especially during the firs...
# 2  수업관련해서는 교수님께 질문을 해도 친절하게 알려주시고, 또 교내에 과제나 발표준비...
#
#                                             etc_info
# 0                                                NaN
# 1  Overall, my stay in Australia has been nothing...
# 2  Bond와 그 동네를 생각하면 여유롭고 평화로웠던 분위기가 아직도 생생해요. 여기서...

# %%
df_ranking_specific = pd.read_csv("/Users/jupiter/Desktop/Exchange_proj/df_univ_wrangled.csv", encoding="utf-8")
df_ranking_specific.head(7)
# Out:
#        대학코드           국가                              대학명  파견구분  협정형태  \
# 0  AF000001  AFGHANISTAN                 Kabul University  교환학생  교환대학
# 1  AR000001    ARGENTINA          Universidad Blas Pascal  교환학생  ISEP
# 2  AR000002    ARGENTINA  Universidad Catolica de Cordoba  교환학생  ISEP
# 3  AR000003    ARGENTINA           Universidad de Palermo  교환학생  ISEP
# 4  AR000004    ARGENTINA         Universidad del Salvador  교환학생  ISEP
# 5  AR000005    ARGENTINA       University of Buenos Aires  교환학생  교환대학
# 6  AU000019    AUSTRALIA   Australian National University  교환학생  교환대학
#
#    NUM_VISITS  BERT_SUM    RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 0         NaN       NaN        NaN       NaN       NaN                  NaN
# 1         NaN       NaN        NaN       NaN       NaN                  NaN
# 2         NaN       NaN        NaN       NaN       NaN                  NaN
# 3         NaN       NaN        NaN       NaN       NaN                  NaN
# 4         1.0       0.0   0.399670   0.00000  0.399670             0.119901
# 5         NaN       NaN        NaN       NaN       NaN                  NaN
# 6        27.0      17.0  17.952732   0.62963  0.664916             0.640216
#
#                                         COLLEGE_LINK
# 0  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 1  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 2  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 3  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 4  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 5  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 6  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking = pd.read_csv("/Users/jupiter/Desktop/Exchange_proj/df_univ_ranking.csv", encoding="utf-8")
df_ranking.head(2)
# Out:
#    index      대학코드           국가  \
# 0    376  CH000004  SWITZERLAND
# 1    284  MX000004       MEXICO
#
#                                                  대학명  파견구분      협정형태  \
# 0                             University of Lausanne  교환학생  교환대학ISEP
# 1  Instituto Tecnologico y de Estudios Superiores...  교환학생  교환대학ISEP
#
#    NUM_VISITS  BERT_SUM   RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 0         8.0       8.0  6.659102       1.0  0.832388             0.949716
# 1         7.0       7.0  5.665700       1.0  0.809386             0.942816
#
#                                         COLLEGE_LINK
# 0  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 1  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking.tail(2)
# Out:
#      index      대학코드      국가  \
# 293    383  TW000005  TAIWAN
# 294    354  ES000017   SPAIN
#
#                                                    대학명  파견구분  협정형태  \
# 293  National Taiwan University, College of Management  교환학생  교환대학
# 294                  Universitat Autonoma de Barcelona  교환학생  교환대학
#
#      NUM_VISITS  BERT_SUM   RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 293         6.0       2.0  3.883967  0.333333  0.647328             0.427532
# 294         7.0       0.0  4.854875  0.000000  0.693554             0.208066
#
#                                           COLLEGE_LINK
# 293  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 294  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking['국가'].value_counts()
# Out:
# UNITED STATES         116
# JAPAN                  23
# CANADA                 17
# NETHERLANDS            14
# AUSTRALIA              13
# UNITED KINGDOM         13
# FRANCE                 12
# GERMANY                11
# CHINA                  10
# SPAIN                   7
# SWEDEN                  6
# AUSTRIA                 6
# HONG KONG               5
# ITALY                   5
# NEW ZEALAND             5
# FINLAND                 4
# TAIWAN                  4
# SINGAPORE               3
# RUSSIAN FEDERATION      3
# SWITZERLAND             3
# IRELAND                 2
# DENMARK                 2
# THAILAND                2
# NORWAY                  2
# ISRAEL                  1
# LITHUANIA               1
# CZECH REPUBLIC          1
# BELGIUM                 1
# MEXICO                  1
# TURKEY                  1
# POLAND                  1
# Name: 국가, dtype: int64

# %%
df_ranking.shape #절반은 어디
# Out:
# (295, 13)

# %%
sample_index=0

# %%
sample_univ = df_ranking.loc[sample_index, '대학명']
sample_univ
# Out:
# 'University of Lausanne'

# %%
sample_univ = df_ranking.loc[sample_index, '국가']
sample_univ
# Out:
# 'SWITZERLAND'

# %%
df_ranking.loc[(df_ranking['대학코드'] == ('CH000004'))]
# Out:
#    index      대학코드           국가                     대학명  파견구분      협정형태  \
# 0    376  CH000004  SWITZERLAND  University of Lausanne  교환학생  교환대학ISEP
#
#    NUM_VISITS  BERT_SUM   RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 0         8.0       8.0  6.659102       1.0  0.832388             0.949716
#
#                                         COLLEGE_LINK
# 0  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking_sw = df_ranking.loc[(df_ranking['국가'] == 'SWITZERLAND')]
print(df_ranking_sw.shape)
# Out:
# (3, 13)

# %%
df_ranking.columns.to_list()
# Out:
# ['index',
#  '대학코드',
#  '국가',
#  '대학명',
#  '파견구분',
#  '협정형태',
#  'NUM_VISITS',
#  'BERT_SUM',
#  'RNN_SUM',
#  'BERT_AVG',
#  'RNN_AVG',
#  'BERT_PLUS_RNN_SCORE',
#  'COLLEGE_LINK']

# %%
df_specific.shape #specific은 왜? 제목은 abstract, specific 은 말뭉치. shape은 대학의 개수.
# Out:
# (470, 11)

# %%
# pandas 설정: 각 column 별 (혹은 한 cell에서) 출력되는 글자수 제한을 없애기
pd.set_option('display.max_colwidth', None)

# %%
df_specific.isnull().sum()
# Out:
# 대학코드            0
# 대학명             0
# gen_info        0
# env_info        1
# food_info       2
# study_info      0
# office_info     8
# facil_info      3
# mhct_info      15
# help_info      17
# etc_info       16
# dtype: int64

# %%
df_column = df_specific.fillna("")
df_column.head(0)
# Out:
# Empty DataFrame
# Columns: [대학코드, 대학명, gen_info, env_info, food_info, study_info, office_info, facil_info, mhct_info, help_info, etc_info]
# Index: []

# %%
df_column.isnull().sum()
# Out:
# 대학코드           0
# 대학명            0
# gen_info       0
# env_info       0
# food_info      0
# study_info     0
# office_info    0
# facil_info     0
# mhct_info      0
# help_info      0
# etc_info       0
# dtype: int64

# %%
import re
# removing junks from the string data
def remove_junk(str_data):
    str_data = str_data.replace("\\\\n", "") #slash n 이 엔터, 쓸데 없는 걸 없애는 거
    str_data = str_data.replace("\\n", "")
    str_data = str_data.replace("\n", "")
    str_data = str_data.replace("\\", "")
    str_data = str_data.replace("\\t", "")
    str_data = str_data.replace("NaN", "")

    # 한글, -english 빼고 전부 날리기
    # regex, regular expression, 특정 글자수 규칙 지정, 말고는 다 날림
    str_data = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', str_data)
    # replace multiple spaces into single space
    str_data = ' '.join(str_data.split()) #멀티플 스페이스를 싱글로 바꿈
    return str_data

# %%
gen_data = 'gen_info'
univ_code = "CH000004"

# %%
def access_univ_info(dataframe, column, univ_code):
    df_row = dataframe.loc[dataframe["대학코드"] == univ_code]
    str_univ_info = df_row[column].to_string(index=False).lstrip()
    str_univ_info = remove_junk(str_univ_info)
    return str_univ_info

# %%
str_example = access_univ_info(df_specific, gen_data, univ_code)
str_example[:500]
# Out:
# '캠퍼스 UNIL은 개정도의 건물들로 이루어져고 건물들 사이의 거리가 생각보다 멀어 전체적인 캠퍼스의 크기는 꽤 큰 편입니다 건물들은 주로 학과들에 따라 나뉘어져있어 주로 수업을 들으실 개정도의 건물만을 이용하게됩니다 자연의 나라 스위스 답게 캠퍼스 또한 아름다운 숲과 냇가를 포함하고 있고 가끔은 건물 앞 잔디밭에 양들을 풀어놓기도 합니다 지리적 위치 로잔은 지하철이 M M 두선밖에 없을 정도로 생각보다 굉장히 작은 도시입니다 모든 곳을 대중교통으로 분 내로 이동이 가능합니다 캠퍼스의 여러 건물들이 띄엄띄엄 위치하여 있는 만큼 위치는 건물들마다 지하철로 짧은 한두정거장 차이가 있지만 모든 건물들은 로잔 내 가장 시내라고 할 수 있는 Lausanne Flon 이라는 역과 지하철로 약 분정도에 위치하여 있습니다 기후 저는 가을학기 월 월 동안 생활했었는데 날씨는 좋은 날도 많았지만 월에는 비가 자주 왔던 걸로 기억합니다 크기 로잔대는 안에 지하철역 개가 있을 정도로 꽤 큰 캠퍼스를 가지고'

# %%
# collecting all column values into one string 여러개의 카테고리별 후기를 하나로 대학으로
def column_to_string(dataframe, column_name: str):
    str_corpus = dataframe[column_name].to_string(index=False).lstrip()
    str_corpus = remove_junk(str_corpus)
    return str_corpus

# %%
# collecting all column values into one string
gen_corpus = str_example
print("글자수:", len(gen_corpus))
gen_corpus[:1000]
# Out:
# 글자수: 3131
# '캠퍼스 UNIL은 개정도의 건물들로 이루어져고 건물들 사이의 거리가 생각보다 멀어 전체적인 캠퍼스의 크기는 꽤 큰 편입니다 건물들은 주로 학과들에 따라 나뉘어져있어 주로 수업을 들으실 개정도의 건물만을 이용하게됩니다 자연의 나라 스위스 답게 캠퍼스 또한 아름다운 숲과 냇가를 포함하고 있고 가끔은 건물 앞 잔디밭에 양들을 풀어놓기도 합니다 지리적 위치 로잔은 지하철이 M M 두선밖에 없을 정도로 생각보다 굉장히 작은 도시입니다 모든 곳을 대중교통으로 분 내로 이동이 가능합니다 캠퍼스의 여러 건물들이 띄엄띄엄 위치하여 있는 만큼 위치는 건물들마다 지하철로 짧은 한두정거장 차이가 있지만 모든 건물들은 로잔 내 가장 시내라고 할 수 있는 Lausanne Flon 이라는 역과 지하철로 약 분정도에 위치하여 있습니다 기후 저는 가을학기 월 월 동안 생활했었는데 날씨는 좋은 날도 많았지만 월에는 비가 자주 왔던 걸로 기억합니다 크기 로잔대는 안에 지하철역 개가 있을 정도로 꽤 큰 캠퍼스를 가지고 있습니다 걸어서 돌려면 꽤 걸릴거예요 제가 많이 안다녀봐서 그렇게 느끼는지는 모르겠지만 길도 조금 복잡한 편이구요 건물과 건물 사이가 되게 넓고 사이사이의 들판에서 양을 키웁니다 잔디를 친환경적으로 관리하기 위해 키운대요 다행히 역이 많은 만큼 지하철에서 건물까지는 꽤 가까워서 수업 들으러 가기는 편합니다 지리적 위치 바로 옆에 레만 호수가 있습니다 오티에서 학과장님이 언급하실 정도로 대표적인 랜드마크예요 여름엔 수영도 하고 바비큐도 한다는데 저는 겨울이고 기숙사도 좀 거리가 있어서 많이는 안 가봤지만 정말 넓고 예뻐요 안개 낀 호수도 예쁘고 요트가 떠있는 것도 볼거리입니다 다만 여름에는 호숫가에 초파리가 좀 많아요 제네바에서 기차를 타면 Lausanne gare 나 Renen역으로 오게 되는데 약 한시간쯤 걸립니다 제네바 반대 방향으로는 Vevey Sion Montreux 가기 전에는 스위스 로잔 지역이 너무 서정적이고 조용한 지방 지역일까봐 걱정이 많았는데 막상 가보니까 그렇지'

# %%
info_list = ['gen_info', 'env_info', 'food_info', 'study_info', 'office_info', 'facil_info', 'mhct_info', 'help_info', 'etc_info']

# %%
for info in info_list:
    corpus_sample = column_to_string(df_specific, info)
    print(info, len(corpus_sample))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-b6dda9bb2be2> in <module>
#       1 for info in info_list:
# ----> 2     corpus_sample = column_to_string(df_specific, info)
#       3     print(info, len(corpus_sample))
#
# <ipython-input-25-64dae42709dd> in column_to_string(dataframe, column_name)
#       2 def column_to_string(dataframe, column_name: str):
#       3     str_corpus = dataframe[column_name].to_string(index=False).lstrip()
# ----> 4     str_corpus = remove_junk(str_corpus)
#       5     return str_corpus
#
# <ipython-input-21-004e033a14ee> in remove_junk(str_data)
#      11     # 한글, -english 빼고 전부 날리기
#      12     # regex, regular expression, 특정 글자수 규칙 지정, 말고는 다 날림
# ---> 13     str_data = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', str_data)
#      14     # replace multiple spaces into single space
#      15     str_data = ' '.join(str_data.split()) #멀티플 스페이스를 싱글로 바꿈
#
# /opt/anaconda3/lib/python3.8/re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# KeyboardInterrupt:

# %%
ch_example = access_univ_info(df_specific, info_list, univ_code)
ch_example[:500]
# Out:
# 'gen info env info food info study info office info facil info mhct info help info etc info 캠퍼스 UNIL은 개정도의 건물들로 이루어져고 건물들 사이의 거리가 생각보다 멀어 전체적인 캠퍼스의 크기는 꽤 큰 편입니다 건물들은 주로 학과들에 따라 나뉘어져있어 주로 수업을 들으실 개정도의 건물만을 이용하게됩니다 자연의 나라 스위스 답게 캠퍼스 또한 아름다운 숲과 냇가를 포함하고 있고 가끔은 건물 앞 잔디밭에 양들을 풀어놓기도 합니다 지리적 위치 로잔은 지하철이 M M 두선밖에 없을 정도로 생각보다 굉장히 작은 도시입니다 모든 곳을 대중교통으로 분 내로 이동이 가능합니다 캠퍼스의 여러 건물들이 띄엄띄엄 위치하여 있는 만큼 위치는 건물들마다 지하철로 짧은 한두정거장 차이가 있지만 모든 건물들은 로잔 내 가장 시내라고 할 수 있는 Lausanne Flon 이라는 역과 지하철로 약 분정도에 위치하여 있습니다 기후 저는 가을학'

# %% [markdown]
# ## Tokenizing with soynlp

# %%
# https://github.com/lovit/soynlp 문장을 쪼개는 방식. 쪼개진 거의 예시가 
from soynlp.tokenizer import RegexTokenizer

tokenizer = RegexTokenizer()
tokenizer

# %%
tokenized_gen = tokenizer.tokenize(ch_example)
tokenized_gen[:30]
# Out:
# ['gen',
#  'info',
#  'env',
#  'info',
#  'food',
#  'info',
#  'study',
#  'info',
#  'office',
#  'info',
#  'facil',
#  'info',
#  'mhct',
#  'info',
#  'help',
#  'info',
#  'etc',
#  'info',
#  '캠퍼스',
#  'UNIL',
#  '은',
#  '개정도의',
#  '건물들로',
#  '이루어져고',
#  '건물들',
#  '사이의',
#  '거리가',
#  '생각보다',
#  '멀어',
#  '전체적인']

# %%
from collections import Counter

# %%
print(len(ch_example))
# Out:
# 22853

# %%
tokenized_gen_counted = Counter(ch_example)
print("no. gen words:", len(tokenized_gen_counted))
common_gen_words = tokenized_gen_counted.most_common(10)
common_gen_words
# Out:
# no. gen words: 695
# [(' ', 5555),
#  ('다', 530),
#  ('는', 478),
#  ('이', 421),
#  ('니', 353),
#  ('에', 352),
#  ('로', 303),
#  ('고', 300),
#  ('하', 294),
#  ('가', 293)]

# %%
min(tokenized_gen_counted, key=tokenized_gen_counted.get)
# Out:
# '냇'

# %%
### WORD2VEC

# %%
stopwords_kr = ['으로', '에서', '있는', '하는', '하고', '있습니다', '그리고','편입니다','아주','곳에','않습니다','좋습니다','않았습니다',
                '입니다', '어느', '하는데', '대체', '있으면', '최근', '좋은','은','있는데','주로',
                '라고', '봅니다', '해야', '있다고', '이라는', '합니다', '조금','굉장히','있으며','것이','갈','자주',
                '경우', '가능한', '하지만', '또한', '처럼', '있어', '보다', '꽤', '상당히',
                '되어', '이미', '그러나', '이루어지고', '이라', '위해', '되면', '와','를', '가지고',
                '이런', '까지', '하여', '우리', '어떤', '에게', '있지만', '해주는', '바로', '내내', '것을', '크게',
                '정도', '또는', '부터', '대해', '모든', '하기', '어떻게', '같습니다', 
                '이라고', '에는', '때문', '되고', '됩니다', '통해', '있을', '결국', '않은','훨씬','같아요','정도의','같습니다','버스를',
                '이를', '특히', '있도록', '대한', '가장', '이나', '에서는', '있고', 
                '같은', '에서도', '아닌', '다른', '따라', '되어야', '한다고', '다만', '볼','도','다'
                '이러한','해서', '관련', '생각', '하지', '않을까요', '약간', '되는', 
                '에선', '라는', '물론', '않을까', '하면', '아니라', '말씀', '에도', 
                '아니라', '부분', '분야', '많은', '여러', '향후', '기반', '행차', '할', '있어서',
                '그러면서', '되지만', '현재', '제가', '저는', '너무', '작은','ity','의','거의','정도로',
                '정말','그들','여타','없으므','완전','몇몇','만약','게다','이후','우선',
                '시쯤','후반','더욱','원하는','많을','몇개','분명','두어개', '하므', '수밖',
                '이','있','하','것','들','되','수','이','보','않','없','나','사람','주','아니','등','같',
                '우리','때','년','가','한','지','대하','오','말','일','그렇','위하','때문','그',
                '그것','두','말하','알','받','못하','일','에','4','10','5', '8','6','9','7','nn','대부분', '오는','꼭'
                '그런','또','문제','더','사회', '는','많이','n','1','2','3','있다','분',
                '많','좋','크','따르','중','나오','가지','씨','시키','만들','지금','생각하',
                '그러','속','하나','살','모르','적','월','데','자신','안','어떤','내','경우',
                '명','그녀','다시','이런','앞','보이','번','다른','어떻','여자','개','전','들',
                '사실','이렇','점','싶','말','정도','좀','원','잘','통하','소리','놓','큰','매우','때문에']

# %%
stops = open('/Users/jupiter/Desktop/Exchange_proj/stopwords_kr.txt', encoding='utf').read()

# %%
stops = open('/Users/jupiter/Desktop/Exchange_proj/stopwords_kr.txt', encoding='utf').read()
kr = open('/Users/jupiter/Desktop/Exchange_proj/stopwords_nogada.txt', encoding='utf').read()

stops_ = stops + kr +'스위스'

# %%
keywords = []
for n in tokenized_gen: 
    if n not in stops_: 
        keywords.append(n)

# %%
common_keywords = Counter(keywords)
common_key_words = common_keywords.most_common(30)
common_key_words
# Out:
# [('ESN', 16),
#  ('FMEL', 15),
#  ('로잔', 13),
#  ('anne', 13),
#  ('EPFL', 13),
#  ('프랑스어', 12),
#  ('Laus', 11),
#  ('수업은', 10),
#  ('Olivier', 10),
#  ('info', 9),
#  ('호수가', 9),
#  ('위치하고', 9),
#  ('수업이', 9),
#  ('위한', 9),
#  ('옆에', 8),
#  ('대학교', 8),
#  ('로잔의', 8),
#  ('스포츠', 8),
#  ('UNIL', 7),
#  ('편입니다', 7),
#  ('지하철로', 7),
#  ('거리에', 7),
#  ('더불어', 7),
#  ('프랑스어를', 7),
#  ('EFLE', 7),
#  ('친절하시고', 7),
#  ('로잔은', 6),
#  ('주변에', 6),
#  ('근처에', 6),
#  ('가끔', 6)]

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 워드클라우드를 위한 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null

# 워드클라우드를 위한 나눔고딕 경로 설정
import matplotlib.font_manager as fm
fontpath = './font/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
backgroundcolor = "white"
width=800
height=600
wordcloud = WordCloud(font_path = fontpath,
                        stopwords = set(stops_), 
                        background_color = backgroundcolor, 
                        max_words= 50,
                        max_font_size= 150,
                        width = width, 
                        height = height)

# %%
wordcloud.generate_from_frequencies(frequencies = common_keywords) # mecab으로 추출한 명사로 워드클라우드를 그린다.
plt.figure(figsize = (15 , 10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
#이래서 전체 스탑워드 뽑은 다음에 각 학교에서 유니크한 거만 정리하는 식으로 하는 거..? 
#아니면 그냥 좋은 거에 대한 대학 0이랑 1 나눠서 그 대학들 키워드만 모아서 알아보기 그 때 그 때 스탑워드 처리.

# %%
word_list, frequency_list = map(list, zip(*common_gen_words))
word_list[:10]
# Out:
# [' ', '다', '이', '는', '니', '에', '을', '하', '고', '도']

# %%
# https://github.com/lovit/soynlp
from soynlp.noun import LRNounExtractor

# %%
from soynlp.noun import LRNounExtractor
noun_extractor = LRNounExtractor()
nouns = noun_extractor.train_extract(keywords)
# Out:
# [Noun Extractor] used default noun predictor; Sejong corpus predictor
# [Noun Extractor] used noun_predictor_sejong
# [Noun Extractor] All 2398 r features was loaded
# [Noun Extractor] scanning was done (L,R) has (305, 160) tokens
# [Noun Extractor] building L-R graph was done
# [Noun Extractor] 47 nouns are extracted

# %%
nouns_counted = Counter(nouns)
print("no. gen words:", len(nouns_counted))
common_nouns = nouns_counted.most_common(100)
common_nouns
# Out:
# no. gen words: 47
# [('몬테레이', NounScore_v1(frequency=22, score=0.9995792, known_r_ratio=1.0)),
#  ('스페인어',
#   NounScore_v1(frequency=21, score=0.9991529166666666, known_r_ratio=1.0)),
#  ('기숙사',
#   NounScore_v1(frequency=13, score=0.5259943333333333, known_r_ratio=0.9230769230769231)),
#  ('공부',
#   NounScore_v1(frequency=11, score=0.9952190000000001, known_r_ratio=0.5454545454545454)),
#  ('파티',
#   NounScore_v1(frequency=10, score=0.7938097142857142, known_r_ratio=0.875)),
#  ('안전',
#   NounScore_v1(frequency=9, score=0.9981421250000001, known_r_ratio=1.0)),
#  ('지역',
#   NounScore_v1(frequency=9, score=0.9445731111111111, known_r_ratio=1.0)),
#  ('이용',
#   NounScore_v1(frequency=9, score=0.87072025, known_r_ratio=0.4444444444444444)),
#  ('학교',
#   NounScore_v1(frequency=9, score=0.8116081111111112, known_r_ratio=1.0)),
#  ('주변',
#   NounScore_v1(frequency=9, score=0.7662653333333334, known_r_ratio=1.0)),
#  ('아파트',
#   NounScore_v1(frequency=9, score=0.7293255, known_r_ratio=0.8571428571428571)),
#  ('이상',
#   NounScore_v1(frequency=8, score=0.9005655999999999, known_r_ratio=1.0)),
#  ('우버', NounScore_v1(frequency=8, score=0.797068, known_r_ratio=1.0)),
#  ('운동',
#   NounScore_v1(frequency=8, score=0.7028078, known_r_ratio=0.7142857142857143)),
#  ('근처',
#   NounScore_v1(frequency=7, score=0.9997255714285715, known_r_ratio=1.0)),
#  ('가격',
#   NounScore_v1(frequency=7, score=0.6494163333333333, known_r_ratio=1.0)),
#  ('국제교육부',
#   NounScore_v1(frequency=7, score=0.5369302857142857, known_r_ratio=1.0)),
#  ('수강', NounScore_v1(frequency=6, score=0.99624025, known_r_ratio=0.8)),
#  ('단체', NounScore_v1(frequency=6, score=0.98897, known_r_ratio=1.0)),
#  ('선택',
#   NounScore_v1(frequency=6, score=0.8333926666666667, known_r_ratio=0.6)),
#  ('생각',
#   NounScore_v1(frequency=6, score=0.7322446666666668, known_r_ratio=1.0)),
#  ('프로그램', NounScore_v1(frequency=6, score=0.628597, known_r_ratio=0.8)),
#  ('교수님', NounScore_v1(frequency=5, score=0.99948925, known_r_ratio=0.8)),
#  ('영어', NounScore_v1(frequency=5, score=0.99883, known_r_ratio=1.0)),
#  ('무료', NounScore_v1(frequency=5, score=0.99883, known_r_ratio=0.75)),
#  ('위치', NounScore_v1(frequency=5, score=0.9945365, known_r_ratio=1.0)),
#  ('교환학생들', NounScore_v1(frequency=5, score=0.87618, known_r_ratio=1.0)),
#  ('물가',
#   NounScore_v1(frequency=5, score=0.8342313333333333, known_r_ratio=1.0)),
#  ('학생들',
#   NounScore_v1(frequency=5, score=0.8020761999999999, known_r_ratio=1.0)),
#  ('도시', NounScore_v1(frequency=5, score=0.68942025, known_r_ratio=1.0)),
#  ('국제학생들',
#   NounScore_v1(frequency=5, score=0.6695443333333332, known_r_ratio=1.0)),
#  ('치안',
#   NounScore_v1(frequency=5, score=0.5979377499999999, known_r_ratio=1.0)),
#  ('정도',
#   NounScore_v1(frequency=5, score=0.5942845999999999, known_r_ratio=1.0)),
#  ('음식', NounScore_v1(frequency=5, score=0.50498175, known_r_ratio=1.0)),
#  ('나라', NounScore_v1(frequency=4, score=0.9993485, known_r_ratio=1.0)),
#  ('느낌',
#   NounScore_v1(frequency=4, score=0.9991850000000001, known_r_ratio=0.75)),
#  ('생활',
#   NounScore_v1(frequency=4, score=0.9973106666666666, known_r_ratio=0.75)),
#  ('좋아', NounScore_v1(frequency=4, score=0.995454, known_r_ratio=1.0)),
#  ('사용',
#   NounScore_v1(frequency=4, score=0.9951756666666668, known_r_ratio=0.75)),
#  ('거주', NounScore_v1(frequency=4, score=0.995127, known_r_ratio=0.75)),
#  ('추천', NounScore_v1(frequency=4, score=0.978997, known_r_ratio=0.25)),
#  ('친절', NounScore_v1(frequency=4, score=0.872487, known_r_ratio=1.0)),
#  ('한국',
#   NounScore_v1(frequency=4, score=0.5000737500000001, known_r_ratio=1.0)),
#  ('클럽', NounScore_v1(frequency=3, score=0.9997615, known_r_ratio=1.0)),
#  ('참여',
#   NounScore_v1(frequency=3, score=0.9630765, known_r_ratio=0.6666666666666666)),
#  ('자연',
#   NounScore_v1(frequency=3, score=0.6697226666666666, known_r_ratio=1.0)),
#  ('한인', NounScore_v1(frequency=2, score=0.999185, known_r_ratio=0.5))]

# %%
noun_extractor.lrgraph.get_r('날씨')
# Out:
# [('는', 5), ('가', 1), ('를', 1), ('의', 1), ('로', 1)]

# %%
noun_extractor.lrgraph.get_l('식당')
# Out:
# []

# %%
print((nouns['학교']))
# Out:
# NounScore_v1(frequency=9, score=0.8116081111111112, known_r_ratio=1.0)

# %%
print((nouns['학교']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-ee8694b5d539> in <module>
# ----> 1 print((nouns['학교']))
#
# KeyError: '학교'

# %%
from soynlp.noun import LRNounExtractor_v2

noun_extractor = LRNounExtractor_v2(verbose=True)
#noun_extractor.train(sents)
#nouns = noun_extractor.extract()
nouns_eo = noun_extractor.train_extract(keywords)
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 346 from 405 sents. mem=0.275 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=405, mem=0.275 Gb
# [Noun Extractor] batch prediction was completed for 175 words
# [Noun Extractor] checked compounds. discovered 0 compounds
# [Noun Extractor] postprocessing detaching_features : 48 -> 48
# [Noun Extractor] postprocessing ignore_features : 48 -> 44
# [Noun Extractor] postprocessing ignore_NJ : 44 -> 44
# [Noun Extractor] 44 nouns (0 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.275 Gb
# [Noun Extractor] 35.80 % eojeols are covered

# %%
nouns_counted_ = Counter(nouns_eo)
print("no. gen words:", len(nouns_counted_))
common_nouns_ = nouns_counted_.most_common(100)
common_nouns_
# Out:
# no. gen words: 44
# [('캠퍼스', NounScore(frequency=12, score=1.0)),
#  ('멕시코', NounScore(frequency=12, score=1.0)),
#  ('몬테레이', NounScore(frequency=9, score=1.0)),
#  ('산', NounScore(frequency=8, score=1.0)),
#  ('지역', NounScore(frequency=5, score=1.0)),
#  ('위치해', NounScore(frequency=4, score=1.0)),
#  ('겨울', NounScore(frequency=4, score=1.0)),
#  ('학교', NounScore(frequency=4, score=1.0)),
#  ('등산', NounScore(frequency=3, score=1.0)),
#  ('날씨', NounScore(frequency=3, score=1.0)),
#  ('공부', NounScore(frequency=3, score=1.0)),
#  ('한국', NounScore(frequency=3, score=1.0)),
#  ('지방', NounScore(frequency=3, score=1.0)),
#  ('여름', NounScore(frequency=3, score=1.0)),
#  ('월', NounScore(frequency=3, score=1.0)),
#  ('우리나라', NounScore(frequency=2, score=1.0)),
#  ('텍사스', NounScore(frequency=2, score=1.0)),
#  ('주변', NounScore(frequency=2, score=1.0)),
#  ('다음', NounScore(frequency=2, score=1.0)),
#  ('크기', NounScore(frequency=2, score=1.0)),
#  ('정도', NounScore(frequency=2, score=1.0)),
#  ('중순', NounScore(frequency=2, score=1.0)),
#  ('주말', NounScore(frequency=2, score=1.0)),
#  ('생각', NounScore(frequency=2, score=1.0)),
#  ('도시', NounScore(frequency=2, score=1.0)),
#  ('번째', NounScore(frequency=2, score=1.0)),
#  ('때', NounScore(frequency=2, score=1.0)),
#  ('떽', NounScore(frequency=2, score=1.0)),
#  ('개', NounScore(frequency=2, score=1.0)),
#  ('저', NounScore(frequency=2, score=1.0)),
#  ('밑', NounScore(frequency=2, score=1.0)),
#  ('초', NounScore(frequency=2, score=1.0)),
#  ('비', NounScore(frequency=2, score=1.0)),
#  ('등', NounScore(frequency=2, score=0.6666666666666666)),
#  ('보', NounScore(frequency=1, score=1.0)),
#  ('대학', NounScore(frequency=1, score=0.5)),
#  ('자연', NounScore(frequency=1, score=0.5)),
#  ('암벽', NounScore(frequency=1, score=0.5)),
#  ('불가', NounScore(frequency=1, score=0.5)),
#  ('경', NounScore(frequency=1, score=0.5)),
#  ('곳', NounScore(frequency=1, score=0.5)),
#  ('내', NounScore(frequency=1, score=0.5)),
#  ('위', NounScore(frequency=1, score=0.5)),
#  ('주', NounScore(frequency=1, score=0.3333333333333333))]

# %%
list(noun_extractor._compounds_components.items())[:50]
# Out:
# []

# %%
print((nouns['마약'])) #LR중요도였는데, counter library가서 순서 매겨야 함
#list 말고 숫자로밖에 순서도 ㄴ
#큐플, 숫자말고 레이블링. 
#tuple 
#generate wordcloud konlpy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-575fb4677442> in <module>
# ----> 1 print((nouns['마약'])) #LR중요도였는데, counter library가서 순서 매겨야 함
#       2 #list 말고 숫자로밖에 순서도 ㄴ
#       3 #큐플, 숫자말고 레이블링.
#       4 #tuple
#       5 #generate wordcloud konlpy
#
# KeyError: '마약'

# %%
# %time df_tokens = df_column.apply(tokenizer.tokenize)

# %%
df_kr = pd.read_csv("/Users/jupiter/Downloads/KSM00047134-data.csv", encoding="utf-8")
df_kr.tail(30)
# Out:
#        #KSM00047134 1977 01 20 00 9999    5          usaf-ds3  366170  1283500
# 79055                     30 -9999  -9999  1500 -9999 -9999 -9999   320   119
# 79056                     30 -9999  -9999  1800 -9999 -9999 -9999   315   134
# 79057                     30 -9999  -9999  2100 -9999 -9999 -9999   310   129
# 79058                     30 -9999  -9999  2400 -9999 -9999 -9999   295   149
# 79059                     30 -9999  -9999  2700 -9999 -9999 -9999   280   170
# 79060                     30 -9999  -9999  3000 -9999 -9999 -9999   255   139
# 79061  #KSM00047134 2000 03 05 00 9999   10          ncdc-gts  366170  1283500
# 79062                     01 -9999  -9999 -9999 -9999 -9999 -9999   110    10
# 79063                     30 -9999  -9999   300 -9999 -9999 -9999   110    26
# 79064                     30 -9999  -9999   600 -9999 -9999 -9999   115    46
# 79065                     30 -9999  -9999   900 -9999 -9999 -9999   110    46
# 79066                     30 -9999  -9999  1200 -9999 -9999 -9999    75    26
# 79067                     30 -9999  -9999  1500 -9999 -9999 -9999    35    26
# 79068                     30 -9999  -9999  1800 -9999 -9999 -9999     5    36
# 79069                     30 -9999  -9999  2100 -9999 -9999 -9999   335    36
# 79070                     30 -9999  -9999  2400 -9999 -9999 -9999   290    46
# 79071                     30 -9999  -9999  2700 -9999 -9999 -9999   260    82
# 79072  #KSM00047134 2000 03 06 00 9999   12          ncdc-gts  366170  1283500
# 79073                     01 -9999  -9999 -9999 -9999 -9999 -9999   140     5
# 79074                     30 -9999  -9999   300 -9999 -9999 -9999   210    36
# 79075                     30 -9999  -9999   600 -9999 -9999 -9999   290    72
# 79076                     30 -9999  -9999   900 -9999 -9999 -9999   305    98
# 79077                     30 -9999  -9999  1200 -9999 -9999 -9999   310   129
# 79078                     30 -9999  -9999  1500 -9999 -9999 -9999   305   154
# 79079                     30 -9999  -9999  1800 -9999 -9999 -9999   300   170
# 79080                     30 -9999  -9999  2100 -9999 -9999 -9999   300   165
# 79081                     30 -9999  -9999  2400 -9999 -9999 -9999   295   154
# 79082                     30 -9999  -9999  2700 -9999 -9999 -9999   290   144
# 79083                     30 -9999  -9999  3000 -9999 -9999 -9999   285   154
# 79084                     30 -9999  -9999  3300 -9999 -9999 -9999   285   185

# %%
df_geo.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-cbcc535c5b66> in <module>
# ----> 1 df_geo.head()
#
# AttributeError: 'str' object has no attribute 'head'
