# %%
# 출력이 너무 길어지지 않게하기 위해 찍지 않도록 했으나 
# 실제 학습 할 때는 아래 두 줄을 주석처리 하는 것을 권장한다.
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# pandas 에서 데이터 뽑고, 말뭉치를 뽑아보면 통으로 분석 못 하니까 형태소로 나누는데 나눈 거 중에
#의미 있는 게 서술어, 나 콜라 먹었다.
#뽑아 내는 거 - wordcloud, konlpy
# Out:
# 1.1.1
# 1.18.5

# %%
# pandas 설정: 모든 row와 모든 column을 출력하게 하고, 각 column 별 출력되는 글자수는 50자 이내 글자수를 50개로 두고, head tail
pd.set_option('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', 50)

# %%
# 위의 설정으로 간단하게 보는 df_specific
df_specific = pd.read_csv("/Users/jupiter/Desktop/Exchange_proj/df_specific_wrangle.csv", encoding="utf-8")
df_specific.head(3)
# Out:
#        대학코드                             대학명  \
# 0  AR000004        Universidad del Salvador
# 1  AU000019  Australian National University
# 2  AU000001                 Bond University
#
#                                             gen_info  \
# 0  아르헨티나의 대다수 대학교는 한국처럼 캠퍼스가 있는 것이 아니라 도시 내에 몇개의 ...
# 1  ANU has a very big campus, but unlike Yonsei, ...
# 2  Bond대학교는 휴양지로 유명한 골드코스트에 위치해있습니다. 서퍼스 파라다이스, 브...
#
#                                             env_info  \
# 0  대학교가 도시 여러곳에 분포하고 있으므로 각기 다르다. 하지만 남녀를 불문하고 부에...
# 1  The city center, called CIVIC, is 20min walk a...
# 2  학교 주변은 조용하고 깨끗한 평화로운 전원마을의 느낌입니다. 학교에서 5분정도 걸어...
#
#                                            food_info  \
# 0  기숙사는 학교에서 제공하지 않고 두가지 옵션이 주어진다. 홈스테이 혹은 게스트 하우...
# 1  There are many housing options, but I chose to...
# 2  거주형태는 크게 On Campus와 Off Campus로 나뉩니다. 저는 기숙사에 ...
#
#                                           study_info  \
# 0  아르헨티나에서의 대학 수업은 주로 오전 혹은 저녁에 있다. 대부분의 학생들이 일을하...
# 1  In my personal opinions, classes are generally...
# 2  수업은 보통 4개의 수업을 듣습니다. 저는 Chinese1, Australian p...
#
#                                          office_info  \
# 0  EL SALVADOR대학교는 국제 교육부가 잘 되있는 학교이다. 아르헨티나 대학교들...
# 1  Overall, I did not have to ask for help much f...
# 2  교환생활 중 국제교육부와 연락할 일은 없었습니다. 교환학생을 가서 따로 국제교육부와...
#
#                                           facil_info  \
# 0  부대시설로는 헬스장이 있다고 알고 있으나 시내와 먼 곳에 있었다. 동아리는 몇가지 ...
# 1  There were many clubs for you to join at ANU, ...
# 2  학기초에 동아리 박람회식으로 여러 동아리들의 부스가 세워집니다. 관심 있는 동아리에...
#
#                                            mhct_info  \
# 0  딱히 컬쳐쇼크를 받을 만 한 요소는 없었던 것 같다. 하지만 처음에 언어적인 면에서...
# 1  I did have some culture shock during my first ...
# 2  특별히 culture shock이라기 보다는 정말 다양한 문화를 접하는 것 자체가 ...
#
#                                            help_info  \
# 0  살바도르 대학교 국제처에서 비자문제나 숙소문제(홈스테이경우) 등은 해결해 주고, 특...
# 1  I was helped a lot, especially during the firs...
# 2  수업관련해서는 교수님께 질문을 해도 친절하게 알려주시고, 또 교내에 과제나 발표준비...
#
#                                             etc_info
# 0                                                NaN
# 1  Overall, my stay in Australia has been nothing...
# 2  Bond와 그 동네를 생각하면 여유롭고 평화로웠던 분위기가 아직도 생생해요. 여기서...

# %%
df_ranking_specific = pd.read_csv("/Users/jupiter/Desktop/Exchange_proj/df_univ_wrangled.csv", encoding="utf-8")
df_ranking_specific.head(7)
# Out:
#        대학코드           국가                              대학명  파견구분  협정형태  \
# 0  AF000001  AFGHANISTAN                 Kabul University  교환학생  교환대학
# 1  AR000001    ARGENTINA          Universidad Blas Pascal  교환학생  ISEP
# 2  AR000002    ARGENTINA  Universidad Catolica de Cordoba  교환학생  ISEP
# 3  AR000003    ARGENTINA           Universidad de Palermo  교환학생  ISEP
# 4  AR000004    ARGENTINA         Universidad del Salvador  교환학생  ISEP
# 5  AR000005    ARGENTINA       University of Buenos Aires  교환학생  교환대학
# 6  AU000019    AUSTRALIA   Australian National University  교환학생  교환대학
#
#    NUM_VISITS  BERT_SUM    RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 0         NaN       NaN        NaN       NaN       NaN                  NaN
# 1         NaN       NaN        NaN       NaN       NaN                  NaN
# 2         NaN       NaN        NaN       NaN       NaN                  NaN
# 3         NaN       NaN        NaN       NaN       NaN                  NaN
# 4         1.0       0.0   0.399670   0.00000  0.399670             0.119901
# 5         NaN       NaN        NaN       NaN       NaN                  NaN
# 6        27.0      17.0  17.952732   0.62963  0.664916             0.640216
#
#                                         COLLEGE_LINK
# 0  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 1  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 2  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 3  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 4  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 5  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 6  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking = pd.read_csv("/Users/jupiter/Desktop/Exchange_proj/df_univ_ranking.csv", encoding="utf-8")
df_ranking.head(2)
# Out:
#    index      대학코드           국가  \
# 0    376  CH000004  SWITZERLAND
# 1    284  MX000004       MEXICO
#
#                                                  대학명  파견구분      협정형태  \
# 0                             University of Lausanne  교환학생  교환대학ISEP
# 1  Instituto Tecnologico y de Estudios Superiores...  교환학생  교환대학ISEP
#
#    NUM_VISITS  BERT_SUM   RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 0         8.0       8.0  6.659102       1.0  0.832388             0.949716
# 1         7.0       7.0  5.665700       1.0  0.809386             0.942816
#
#                                         COLLEGE_LINK
# 0  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 1  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking.tail(2)
# Out:
#      index      대학코드      국가  \
# 293    383  TW000005  TAIWAN
# 294    354  ES000017   SPAIN
#
#                                                    대학명  파견구분  협정형태  \
# 293  National Taiwan University, College of Management  교환학생  교환대학
# 294                  Universitat Autonoma de Barcelona  교환학생  교환대학
#
#      NUM_VISITS  BERT_SUM   RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 293         6.0       2.0  3.883967  0.333333  0.647328             0.427532
# 294         7.0       0.0  4.854875  0.000000  0.693554             0.208066
#
#                                           COLLEGE_LINK
# 293  http://oia.yonsei.ac.kr/partner/expReport.asp?...
# 294  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking['국가'].value_counts()
# Out:
# UNITED STATES         116
# JAPAN                  23
# CANADA                 17
# NETHERLANDS            14
# UNITED KINGDOM         13
# AUSTRALIA              13
# FRANCE                 12
# GERMANY                11
# CHINA                  10
# SPAIN                   7
# SWEDEN                  6
# AUSTRIA                 6
# ITALY                   5
# NEW ZEALAND             5
# HONG KONG               5
# FINLAND                 4
# TAIWAN                  4
# SINGAPORE               3
# SWITZERLAND             3
# RUSSIAN FEDERATION      3
# IRELAND                 2
# DENMARK                 2
# THAILAND                2
# NORWAY                  2
# CZECH REPUBLIC          1
# TURKEY                  1
# MEXICO                  1
# BELGIUM                 1
# POLAND                  1
# ISRAEL                  1
# LITHUANIA               1
# Name: 국가, dtype: int64

# %%
df_ranking.shape #절반은 어디
# Out:
# (295, 13)

# %%
sample_index=0

# %%
sample_univ = df_ranking.loc[sample_index, '대학명']
sample_univ
# Out:
# 'University of Lausanne'

# %%
sample_univ = df_ranking.loc[sample_index, '국가']
sample_univ
# Out:
# 'SWITZERLAND'

# %%
df_ranking.loc[(df_ranking['대학코드'] == ('CH000004'))]
# Out:
#    index      대학코드           국가                     대학명  파견구분      협정형태  \
# 0    376  CH000004  SWITZERLAND  University of Lausanne  교환학생  교환대학ISEP
#
#    NUM_VISITS  BERT_SUM   RNN_SUM  BERT_AVG   RNN_AVG  BERT_PLUS_RNN_SCORE  \
# 0         8.0       8.0  6.659102       1.0  0.832388             0.949716
#
#                                         COLLEGE_LINK
# 0  http://oia.yonsei.ac.kr/partner/expReport.asp?...

# %%
df_ranking_sw = df_ranking.loc[(df_ranking['국가'] == 'SWITZERLAND')]
print(df_ranking_sw.shape)
# Out:
# (3, 13)

# %%
df_ranking.columns.to_list()
# Out:
# ['index',
#  '대학코드',
#  '국가',
#  '대학명',
#  '파견구분',
#  '협정형태',
#  'NUM_VISITS',
#  'BERT_SUM',
#  'RNN_SUM',
#  'BERT_AVG',
#  'RNN_AVG',
#  'BERT_PLUS_RNN_SCORE',
#  'COLLEGE_LINK']

# %%
df_specific.shape #specific은 왜? 제목은 abstract, specific 은 말뭉치. shape은 대학의 개수.
# Out:
# (470, 11)

# %%
# pandas 설정: 각 column 별 (혹은 한 cell에서) 출력되는 글자수 제한을 없애기
pd.set_option('display.max_colwidth', None)

# %%
df_specific.isnull().sum()
# Out:
# 대학코드            0
# 대학명             0
# gen_info        0
# env_info        1
# food_info       2
# study_info      0
# office_info     8
# facil_info      3
# mhct_info      15
# help_info      17
# etc_info       16
# dtype: int64

# %%
df_column = df_specific.fillna("")
df_column.head()
# Out:
#        대학코드                              대학명  \
# 0  AR000004         Universidad del Salvador
# 1  AU000019   Australian National University
# 2  AU000001                  Bond University
# 3  AU000002                Curtin University
# 4  AU000003  Curtin University of Technology
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1  ANU has a very big campus, but unlike Yonsei, everything is pretty flat aka there're no steep heels that you have to walk to get to classes. The buildings are tall, modern, and Kambri - the university main walking lane - is a great spot for students gathering with lots of restaurants, cafes and a lawn with bean bags for students to lie on. July-August in Canberra is winter, so the weather is quite chilly but nice. There was no snow, some light rain so nobody in Canberra uses an umberella. By... ANU는 Civic이라는, 캔버라에서 가장 중심이 되는 도심 부근에 위치하여 접근성이 좋습니다. 캔버라가 시드니, 멜버른에 비해 소도시라는 느낌이 강해 선호도가 낮은 듯 한데요. (저 또한 퀸즐랜드가 1지망이었습니다) 1학기를 지내며 아주 안전하고 깨끗하며 잘 만들어진 도시라는 인상을 받았습니다. 행정수도라 거주하는 사람 중에 공무원이나 학교 관계자 비율이 높은 듯 하구요. 따라서 생활수준이 높아 저 포함 친구들 또한 캔버라에서는 차별을 경험해본 적이 없습니다. 굳이 비교하자면 송도와 흡사한 느낌이지요. 다만 바다가 없기 때문에 기후는 타 도시에 비해서 건조한 편입니다. 날씨는 한국에 비해 연교차가 적다는 느낌을 받았구요. 호주 어디를 가든 날씨는 만족하실 거에요. 연중 대부분이 야외활동 하기 좋은 날씨입니다. 대학교는 상당히 넓은 편입니다. 전공 수업을 듣다가 다른 단과대 건물로 이동하는게 쉽지는 않았습니다. 시간표 짤 때 주의하시면 좋겠습니다. 학교에서 센터까지는 그리 멀지 않습니다. 걸어다니기 충분한 거리이고, 밤에는 기숙사를 돌아주는 셔틀버스가 있는데 Unilodge 쪽에서 내리시면 쉽게 갈 수 있습니다.캔버라는 시드니와 멜버른 그 사이쯤에 있는데 시드니에서 조금 더 가깝습니다. 시드니에서 3시간 반 정도 버스를 타고 가야 합니다. 다른 먼 지역 혹은 다른 나라로의 여행을 생각 중이시라면 시드니 쪽 대학을 추천드립니다. 캔버라에도 공항이 있기는 하지만 비행기표가 비싼 편이라 급할 때 말고는 이용하지 못했습니다.저는 2월부터 7월까지 생활했는데 호주 계절로는 여름부터 겨울 정도입니다. 여름에는 햇빛은 매우 뜨거우나 습도가 높지 않아 한국보다 훨씬 좋습니다. 제가 묵었던 기숙사는 Fenner hall로 에어컨이 없었음에도 불구하고 괜찮았습니다. 가을이 꽤 긴 편으로 기억 납니다.... ANU는 호주의 수도 캔버라에 위치해 있습니다. 시드니랑 가까울줄 알았는데 버스타고 3시간~4시간정도 타고 가야합니다. 근데 호주가 워낙 커서 이정도면 다닐만한듯 하기도 합니다. 날씨는 너무너무 좋습니다! 여름에도 건조한 더위라서 그늘에선 선선하고, 겨울도 호주치고는 추운편이지만 우리나라에 비하면 살만합니다. 다만 일교차가 커서 감기걸리기가 쉽습니다. 크기는 꽤 큰 편이구 하나의 공원같습니다. 그런데 사실 계속 다니는 건물만 다녀서 다른데는 잘 안다녔던 것 같습니다. 기숙사에서 걸어서 15분?정도에 웬만한 곳들을 다 갈 수 있었던 것 같습니다. ANU 캠퍼스는 매우 넓습니다. 자연대와 공대를 복수전공하고 있어서 강의실 간 거리가 상당했습니다. 자전거를 구입했고 초반에는 타고다니면서 10-15분이내로 강의실에 도착할 수 있었지만 모든 수업이 동영상으로 제공이 되었기 때문에 수업 앞부분을 놓쳤더라도 동영상으로 커버할수 있습니다. 캔버라는 아주 평화롭고 자연친화적인 도시이며 가까운 곳 중 갈 만한 곳이 큰 쇼핑몰 한군데 밖에 없습니다. 이런 점에서 지리적 위치는 꽤 안좋다고 생각합니다. 저는 2학기를 다녔고 당시 날씨는 꽤 추웠습니다. 패딩을 가져가진 않았지만 두꺼운 코트를 입어야 했습니다. 한달쯤 지나니 날씨가 꽤 풀렸고 막판에는 봄날씨를 즐기다 왔습니다. Australian National University(ANU)는 호주의 수도 캔버라에 위치해있습니다. ANU는 호주에서 가장 우수한 대학으로 세계 명문대로서의 명성을 이어가고 있습니다. ANU의 캠퍼스는 연세대학교의 캠퍼스보다 훨씬 크며 날씨가 좋은 날에는 공원에 온듯한 기분이 들만큼 친자연적인 캠퍼스 환경을 유지하고 있습니다. 봄학기에 기후는 대체로 온화한 편이며, 맑고 예쁜 하늘을 감상하실 수 있습니다. 캔버라가 크고 한적한 곳인 만큼 캠퍼스가 굉장히 큽니다. 많은 수업을 들으신다면 수업 중간 쉬는 시간에 다른 건물로 이동하는데 걸어서 시간이 상당히 소요됩니다. 저는 자전거를 따로 구입하지 않고 항상 걸어다녔는데, 사실 좀 힘들었지만 운동이 되었습니다. 오래 계실 계획이라면 자전거를 중고로 저렴하게 구입하시는 것을 추천합니다. 캔버라는 시드니와는 차로 3시간 반 정도 떨어져있고 멜버른에서는 차로 7~8시간이 소요됩니다. 따라서 자주 시드니나 멜버른으로 놀러가기에는 부담스러우나, 가끔 캔버라가 지겨울 때는 시드니로의 짧은 여행을 추천드립니다. 또한 캔버라에 공항이 있으나 비행기값이 매우 비싸고 또 항공편도 적습니다. 그러므로 시드니까지 가서 비행기를 타야하는데, Murrays에서 티켓을 샀습니다. 계정을 만들어 일정 횟수 이상타면 무료 쿠폰이 나오니 이용하시길 바랍니다. 저는 2월부터 1학기 동안 지냈는데 남반구에 위치한 만큼 우리나라와 정반대의 계절로 점점 추워졌습니다. 하지... 우선 학교 캠퍼스 엄청엄청 커요! 학교 내에서도 자전거 타고 다니는 사람이 대다수고, 전공별로 빌딩이 멀리멀리 있는 경우도 많아서 수강신청하실 때 꼭 빌딩 위치 확인하시는 것을 추천드립니다. 학교가 Canberra Centre와 10~15분 정도 걸어서 걸리는 거리에 있어서 보통 장볼 것이 있거나 쇼핑할 것이 있으면 학교 끝나고 자전거 타고 다녀요. 날씨는 좋을 때는 엄청 좋고 시드니, 멜버른 등과 같은 도시와는 다르게 한적하고 조용합니다. 학교 진짜 엄청 큽니다. 막 이거저거 여러 과 수업 들으셔서 건물 막 흩어져 있는 곳으로 수업 들으러 가면 꽤 힘들 수도 있어요. 학교 안에서 자전거 타고 다니는 사람들도 많구요. 1년 동안 다니면서 저는 전공 수업 위주로 들었기 때문에 같은 건물 혹은 모여 있는 건물에서 수업을 들었습니다. 그래서 그 범위 살짝 벗어나도 아예 모르는 새로운 학교의 공간이 나오곤 했어요.여름에는 생각보다 꽤 덥습니다. 제가 겪어본 적은 없지만 40도 넘어가는 경우도 종종 있다네요. 겨울에는 춥구요. 물론 개인적인 차이는 있겠지만요. 호주 있을 떄 여기 춥다 혹은 여기 덥다 그러면 한국은 여름에 장난 아니었다, 겨울 날씨 미쳤다 하는 소리륻 듣곤 했는데 어디든 자기가 경험하는 주관적인 온도가 제일 덥고 제일 춥습니다.캔버라 자체는 별로 볼 게 없어서 시드니나 멜번으로 여행가곤 했습니다. 근데 캔버라가 시드니랑 멜번 중간 지점이라고 수도로 정했다고 하던데 무슨 중간 지점이라는 건지 공항이나 기차 ... ANU는 호주의 수도 캔버라에 위치해 있습니다. 시드니에서 약 3시간 정도 버스를 타시면 캔버라에 도착할 수있습니다. 시드니에서 캔버라까지 공항이 있긴 하지만 비행기 표가 약 10만원이고 공항에서 학교까지 또 택시를 타야 하기 때문에 추천하지는 않습니다. 넓은 땅으로 유명한 호주답게 ANU 캠퍼스는 굉장히 넓습니다. 하지만 학교 B&G 기숙사에서 유니로지까지 걸어서 약 15분정도 걸리는 것으로 보았을 때 연대 캠퍼스의 크기와 거의 비슷하다고 생각이 됩니다. 하지만 연대와는 다르게 대부분 평지이기 때문에 BIG W나 학교 페이스북 Free&For Sale 그룹에서 자전거를 구입하셔서 다니시는것도 추천합니다. 캔버라는 해발고도 약 600m에 위치하고 있습니다. 따라서 비슷한 위도의 호주의 다른 도시들보다 약간 쌀쌀합니다. 7월에 처음 도착했을때 하루기온이 대체적으로 0℃~10℃정도 차이났었습니다. 하루의 초봄 날씨 ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Bond대학교는 휴양지로 유명한 골드코스트에 위치해있습니다. 서퍼스 파라다이스, 브로드비치 등등 아름다운 해변가가 인접해있습니다. 테마파크나 동물원 등 주말마다 갈 곳이 많아 바쁜 주말을 보내게 되실거에요!날씨는 제가 도착했던 9월은 꽤 쌀쌀했습니다. 여름만을 생각하고 두꺼운 옷을 충분히 챙기지 않아 더 춥게 보냈던 것 같습니다. 기본적으로 햇빛 아래에서는 따뜻하지만 바람이 많이 불고 건조한 날씨이기 때문에 그늘에서는 선선하거나 혹은 쌀쌀합니다. 9월은 가을의 느낌이었고 11월쯤 부터는 정말 여름이라고 느껴지는데 호주의 햇빛은 정말 강하기 때문에 선블록이 필수입니다. Bond 대학교는 호주 동부 해안선에 위치한 골드코스트라는 도시에 위치해 있습니다다. 골드코스트는 퀸즈랜드에서 세번째로 큰 도시로 '서퍼스 파라다이스'라는 휴양지를 중심으로 발달되어 있습니다. 학교 앞 정류장에서 버스를 타고 20분만 나가면 서퍼스 파라다이스에 갈 수 있습니다. 정말 맘만 먹으면 매일 해변에 갈 수 있는 위치이죠! 서퍼스 파라다이스는 서핑으로 전세계적으로 유명한 곳이고 해운대 처럼 해변과 도시가 어울어져 있는 번화가 입니다. 그 곳에는 한인 슈퍼마켓과 한인 식당도 있어 친구들과 삼겹살을 먹으로 자주 갔었습니다. Bond대학교의 크기는 우리학교의 절반도 안되는 크기로 매우 작고 학생수도 매우 적습니다. 또 교환학생 수가 굉장히 많아 전체 학생수의 절반가량 됩니다. 호주는 남반구니까 9월에 갈 때 여름일거라고 생각해서 여름 옷이랑 가디건 후드 짚업 정도만 가져 갔었는데 생각보다 추웠습니다. 우리나라 가을이나 초봄 날씨로 호주는 햇빛이 강하기 때문에 낮에는 반팔... 본드 대학은 일단 그렇게 크지는 않습니다. 지리적 위치는 골드코스트라는 휴양도시에 위치해 있지만 약간 깊숙한 곳에 있어 주변에 번화가는 없습니다. n그리고 기후는 우리나라와 반대계절이고 대체적으로 습하지 않고 굉장히 따스합니다. 햇볕이 강하므로 선크림은 필수이고 일교차가 클 때도 있으므로 두터운 옷을 준비하시는 것이 좋습니다. n선글라스 역시 필수아이템이라고 볼 수 있습니다. Bond는 호주의 대표 휴양지 골드코스트에 있습니다. 기차로 브리즈번과 한시간 거리입니다. 휴양지인만큼 날씨는 1년 내내 따뜻한 편인데, 가끔 비가 오거나 쌀쌀한 날씨에는 여름이라도 간절기용 아우터가 필요한 정도에요. 제가 간 9월은 초여름 날씨였어요. n캠퍼스는 연세대학교와 비교했을때 아주 작은 편입니다. 큰 건물 대여섯개로 이루어져있 ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          curtin university는 서호주 퍼스에 위치한 대학입니다. 퍼스는 서호주에서 가장 큰 도시이며, 호주에서 5번째로 큰 도시이기는 하지만 한국과 비교하면 지방 시도시 정도의 도시입니다.curtin university는 서호주에서 가장 큰 대학입니다. 연대보다 매우 캠퍼스도 크고 건물도 더 많아서 처음에는 길찾기 힘들 수 있으니 개강 전에 도착해서 강의실 위치와 주요 건물 위치를 파악하는 것이 좋을 것 같습니다. 또한 lost in campus 앱을 이용하는 것도 좋을 것 같습니다.퍼스는 한국과 비교하면 따뜻합니다. 늦여름-초겨울 정도의 시기에 퍼스에 있었는데 두툼한 가디건이나 후리스, 얇은 재킷 정도면 충분히 버틸 수 있습니다. curtin university는 서호주에서 가장 큰 캠퍼스를 가지고 있지만 연세대학교 캠퍼스보다는 작습니다. 공대가 유명한 대학이라고 하더군요. 아시다시피 호주는 계절이 한국과 반대입니다. 8월 초에 봄학기가 시작되어 11월 말에 끝나는데, 겨울은 12도 정도로 우리나라보다 춥지 않은 날씨이며 비가 자주 오긴 하지만 해가 뜨면 완연한 봄처럼 따뜻합니다. 달이 갈수 ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1  The city center, called CIVIC, is 20min walk away from the campus. It's a very nice walk. The streets aren't that crowded and there are a wide range of restaurants in Civic that you can choose, ranging from Mexican, Chinese, American, etc. In Civic there are IKEA, Coles (go-to mall for grocery shopping) and other fashion stores like Cotton On, H&M, etc. Nightclub in Canberra is great, and students' night is every Thursday, not Friday or Saturday. ANU has a very nice responsible drinking cult... 캠퍼스 자체는 자연입니다. 정문에서 걸어서 10분 정도면 Centre라고 생긴지 얼마 안된 큰 쇼핑센터가 있구요. 마트, 영화관, 클럽 등 전부 가까워요. 물론 캔버라 자체가 작은 도시입니다만, 그래서 기숙사에만 거주하신다면 대중교통을 거의 이용할 필요 없다는 장점이 있습니다. 행정 수도기 때문에 웬만한 것은 다 갖추어져있기도 하구요. 또 Burley Griffin이라는 커다란 인공 호수와 아주 가까운데요. 정말 아름다운 호수입니다. 조깅, 자전거 라이딩 도로를 따라 내려가면 작은 들판이 나오는데요 거기서 보았던 노을은 평생 잊을 수 없을 듯 합니다. 대학교 주변에 센터가 있고, 그 곳에 술집과 영화관, 카페 등이 있지만 거기를 빼고는 사실 놀거리가 많지는 않습니다. 연세대 주변 환경과는 거의 반대라는 점 감안하시고 가시길 바랍니다. 자연을 좋아하시고 고요함을 즐기시는 분들께 추천드립니다. Commonwealth park라는 공원이 호수가 굉장히 크고 좋아서 추천드립니다. 정말 깨끗하고 아름다운데 사람도 많지 않아서 정말 좋습니다. Mount Ainslie라는 곳도 추천드립니다. Fenner hall에서 2-30분 걸어가면 되는데요, 나무들도 멋있고, 경치도 좋고, 무엇보다 말로만 듣던 캥거루들이 풀을 뜯고 있습니다. 캥거루들이 정말 많이 있는데 우리 같은 것도 없이 볼 수 있습니다. 너무 가까이 가지 않는 이상 공격은 하지 않습니다. Botanic garden과 Old Bus Depot Markets도 추천드립니다. 화려한 것들은 많이 없지만 최대한 열심히 찾아서 다니시길 바래요ㅎㅎ 한국 돌아오니까 그런 자연들이 너무 그... 캔버라는 사실 번화한 도시가 아닙니다. 호주의 수도이지만 정말 수도의 역할만 합니다. 시드니가 뉴욕이라면 캔버라는 워싱턴 같은 곳이죠! 학교에서 1키로정도에 캔버라 가장 중심부인 시내가 있습니다. 쇼핑몰도 있고, 한국 코인노래방도있고 (비싸지만) 음식점도 꽤나 많습니다. 하지만 별다른 놀거리는 크게 없습니다! 저는 막 화려한 밤문화를 좋아하지 않아서 만족했지만 TV에서 생각하던 유학생들의 화려한 삶을 꿈꾼다면 좀 실망하실수도있습니다. 목요일은 클럽이 무료입장입니다. 큰 쇼핑몰 말고는 별거 없습니다. 필요한건 웬만큼은 다 있습니다. ANU에서 Civic까지는 걸어서 10~15분 정도로 아주 가까우며, 대학 주변에 양식을 비롯해 여러 아시아(한국, 중국, 일본, 베트남, 말레이시아) 식당들이 위치해있습니다. 참고로 한인마트가 대학에 정말 가깝게 위치해있습니다. 캔버라 센터에서 걸어서 15분 정도로 중심에서 멀지 않은 곳에 위치해있습니다. 하지만 캔버라 자체가 매우 고요하고 한적하여 서울처럼 붐비거나 재밌는 night life를 기대할 순 없습니다. 저는 한적한 시골분위기를 좋아하시는 분이라면 캔버라 생활에 잘 적응하실 수 있다고 생각합니다. 학교에서는 조금 떨어져 있으나 버스를 타고 가면 Commonwealth park가 있는데 호수를 따라 산책하는 것을 즐겨했습니다. Braddon, Canberra central에서 주로 수업 끝나고 친구들과 식사를 하거나 쇼핑, 식료품을 사러 나갔습니다. 차가 있는 친구를 만난다면 Belconnen이나 Mitchell, Kingston을 가기도 하였는데 특별한 것은 없습니다. 캔버라에서 가장 유명한 것은 Australian War Memorial인 것 같습니다. 또한 National Arboretum, Botanic garden이나 National gallery도 시간 날 때 심심하다면 방문하실... 캔버라 중심 시내가 학교 근처에 있어요. 그런데 사실 식당이며 뭐며 별거 없어요. 캔버라 자체가 일단 큰 도시가 아니고 행정도시이기때문에, 행정건물같은 사무실이 많고 놀만한 곳이나 그런 곳은 기대하지 않는 것이 좋아요. 공부하기에는 최적의 환경입니다. 센터 말고도 시내라고 불릴 수 있는 곳들이 몇 군데 있긴 한데 나머지는 다 버스타고 다녀야하는 조금은 먼 곳에 위치해 있어요. 그러나 대형마트, 음식점, 한인마트 등등 정도는 주변에 있습니다. 학교 주변에 걸어서 한 10분? 정도에 캔버라 센터가 있는데 그 안에 생활에 필요한 대부분의 용품은 다 살 수 있습니다. 아마 캔버라에서 사람 가장 많은 곳 중에 하나일 것 같네요. 그 안에 콜스 있는데 이마트나 홈플러스 같은 엄청 큰 마트이구요 그 외에도 센터 안에 엄청 많습니다. 건물이 우리나라처럼 높게 위로 솟아 있지 않고 넓게 퍼져 있어서 걷다 보면 어느새 들어온 입구와는 아예 다른 곳으로 나와 있는 자신을 발견할 수 있습니다. 캔버라가 워낙 작은 도시여서 갈만한 것들 오밀조밀하게 다 모여 있습니다. 캔버라 센터 주변으로 식당이나 카페 다 몰려 있고요 센터 주변 살짝만 벗어나도 진짜 황량합니다. 한번은 도시 탐험한다고 여기저기 돌아다녀봤는데 별것도 없고 더럽게 춥기만 했습니다. ANU 자체가 캔버라 중심에 위치하고 있기 때문에 생활하는데는 딱히 불편함이 없었습니다.시내 중심가를 Civic이라고 부르는데, 그곳에 식당, 쇼핑몰, 도서관, 영화관 등 모든 시설들이 모여있습니다. 한인식당에 가보지는 않았지만, 한인식당도 4군데 정도 있었고, 한인마트도 civic에 kim's grocery, 학교 앞 uni pub 건물에 e-mart 라는 곳들이 있는데 그곳에서 한국음식들을 사먹고 한국으로 택배도 부칠수 있습니다. kinloch lodge에 아시안마켓이 있으나 한국음식보다는 중국이나 동남아 음식이 많았기 때문에 자주 이용하지는 않았습니다. 학교 바로옆에 Black Mountain, Griffin Lake 등이 있어서 주말에 친구들과 산책을 나가기도 하였습니다. One thing about ANU is that I always felt quite safe despite being in a completely new country. This was due to the school's strict provisions of campus safety facilities, such as an ANU distress call app, ANU Security Patrols, and most significantly the campus shuttle buses that you could call to take you from one place to another in the evenings or during the day. This not only provided easy and free transport from one spot of the campus to another, but also allows for you to stay out late... 걸어서 15분 정도 거리에 Civic이라 불리는 번화가가 있으나, 캠퍼스 근처에는 편의시설이 거의 없고 한산합니다. 주변에 녹지가 많고 Burley griffin이라는 큰 호수와 인접하고 있어 산책하기는 매우 좋습니다. 캠퍼스에서 10 - 15분 정도 걸으면 Civic이라 불리는 중심부에 닿을 수 있는데, 이곳에는 각종 행정기관 건물들과 상점들이 모여 있습니다. Civic의 중심부에는 Canberra Centre라는 ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          학교 주변은 조용하고 깨끗한 평화로운 전원마을의 느낌입니다. 학교에서 5분정도 걸어나가면 Market Square라는 곳에서 식당, 병원, 약국, pub, 마트 등을 이용할 수 있습니다. 괜찮은 식당들이 꽤 있기 때문에 친구들과 밖에서 밥을 먹을 땐 보통 이곳에서 먹었습니다. 호수를 주변으로 산책로도 예쁘게 되어있기 때문에 산책하기에도 좋습니다. 15분정도 버스를 타고 나가면 Robina center입니다. 이곳은 대형몰로 쇼핑하기에 좋은 곳입니다. 호주의 대형마트인 Woolworth, Coles 등이 전부 위치해있습니다. 버스와 트램을 타고 30분정도 나가면 서퍼스파라다이스 입니다. 아름다운 해변을 중심으로 한 번화가로 활기찬 느낌입니다. 이곳에는 한식당과 한인마트가 있어 종종 이용하였고, 밤에 열리는 마켓도 구경할 만 합니다. 학교 근처는 신촌역 근처와 엄청난 차이가 있습니다. 신촌 주변처럼 번화가도 아니고 유동인구도 그렇게 많지 않습니다. 학교에서 3분 정도만 걸어가면 마켓스퀘어라는 음식점들과 편의점들이 모여있는 곳이 있습니다. 학교 내 식당은 비싸고 맛도 없어서 기숙사에 살지 않는 학생이나 기숙사에 사는 학생들도 학기 후반에는 주로 마켓스퀘어에 있는 식당에서 밥을 먹었습니다. 그 곳에는 중국식당, 스시집, 태국식당, 서브웨이, 피타핏, 이탈리아 레스토랑 등의 식당이 있습니다. 아쉽게도 한국식당은 없습니다. 식당 운영시간도 한국과는 다른 점이 있는데 대부분 식당은 9시쯤 문을 닫고 Pub이라고 하더라도 제일 늦게까지 하는 곳이 12시면 문을 닫습니다. 그리고 마켓스퀘어 근처에 호수가 있는데 산책하기 정말 좋은 곳입니다. 그리고 동네가 전체적으로 정말 평화롭고 한가로운 분위기였습니다. 그리고 동네 주민분들도 친절하셔서 살기에 정말 좋은 동네였습니다. 교환학생을 떠나기 전에는 호주 안전에 대해 정말... 약 20분 정도 거리에 서퍼스 파라다이스(surfer’s paradise)라는 지역이 있는데 이 곳이 바로 번화가 입니다. 평소에도 물론 많은 사람들이 모이는 곳이지만 호주의 긴 휴일이 4월에 있는데 이 때 엄청난 인파가 이 곳에 몰립니다. 그리고 12월부터는 일본인들이 정말 많이 몰리는 곳이기도 합니다. 그리고 가까운 곳에 로비나 타운 센터나 퍼시픽 페어 같은 쇼핑몰 비슷한 곳들이 있는데 이 곳 안에 대형 마트들이 있어 식료품 및 기타 필요 물품을 구입하시면 좋을 것 같습니다. 호주 물가가 조금 비싼 편인데 이 곳은 나름 괜찮은 가격대인 것 같습니다 (시간이 지나면 엄청 싸다는 느낌을 받음) 학교 주변은 조용합니다. 심지어 제가 살고 있는 기숙사 바로 옆에는 실버타운 건물이 있을 정도로 평화로운 동네에요. Varsity lake를 중심으로 Market square, Varsity college에 걸쳐 상권이 형성되어 있습니다. 상권이라고 해봤자 작은 레스토랑과 가게들이 전부인데요. 레스토랑들은 학교 식당과 비교하면 맛있고 좀 더 저렴한 편이에요. 편의점이 두어개 있는데 비싼 편이라서, 쇼핑은 대형마트에서 하는게 훨씬 낫습니다. 그 외에 가까운 거리에 약국이나 병원도 있어 편리합니다. n정문 앞 버스정류장에서 버스를 타면 15분 거리에 Robina town centre가 있는데, 호주 대형마트인 coles와 woolsworth를 포함한 다양한 쇼핑몰들이 입점해 있습니다. Bond 학생들이 주로 쇼핑하는 곳이에요. n버스 타고 20분 거리에는 기차역이 있고, 한시간 거리에는 골드코스트 공항이 있습니다. 대학교 근처에는 학생들이 사는 작은 건물들과 집들, marketsqure가 있습니다. marketsqure에는 다양한 식당들이 있기 때문에 학교 식당에 질릴 경우, 시도해 볼만 합니다. 스시집과 take out 스시를 많이 먹고, 흔히들 아는 패스트푸드점은 없으나 fish and chips를 파는 가게는 있습니다. 한국사람이 하는 한국식당도 있었는데 4월에인가 가게가 빈 것으로 봐서 아자 폐업하지않았나 싶습니다. 편의점과, IGA 슈퍼마켓은 밤 늦게까지 운영하기 때문에 많은 학생들이 이용하지만, 가격이 비싼 편이라 장을 많이 볼 경우 버스를 타고 Robina town centre, Pacific fair의 대형 수퍼마켓(Coles, Woolworth 등)을 이용합니다. 학교도 평소에 시끄럽지않은데다(학교내 술집겸 클럽말고는 ㅋ)대학주변은 단조롭고 한적하기 때문에 학교 근처에서 주말이나 휴일을 보낸다면 지루할 수도 있습니다. 많은 학생들이 쉬는날에는 근처 교회(hope''s c... 일단 본드대학교는 브리즈번, 시드니, 멜번같은 대도시에 인근한 대학교가 아니라 골드코스트 근처, 그것도 바로 골드코스트 시내 옆에 아닌 조금 떨어진 곳에 위치해 있기 때문에 주변은 굉장히, 아주 굉장히 한적하다. 한 마디로 동네가 아주 조용하다고 할 수 있다. 주변에 학생들을 위한 원룸이나 집들은 많은데 지나다니다 보면 항상 조용하고 사람이 많이 다니는 것을 본적이 없다. 학교 주변 술집은 가까운 곳에 3 군데 정도 있고 3군데 모두 각기 떨어져 있다. 신촌과 같은 북적거리는 곳에서 학교를 다니다 가면 너무 한적하고 조용해서 적응이 안될 수도 있다. 그런 분위기를 좋아한다면 상관없겠지만 대체적으로 학교도 연세대학교처럼 사람이 바글거리지 않고 조용하다. 신촌의 대학생활에 익숙해져있는 사람에게 본드 대학교는 추천하지 않겠다. 평소 생각하고 있던 대학 생활을 기대하고 가서는 크게 실망할 것이다. nn앞서 말했듯이 한적한 곳에 주변엔 주택가들이 대부분이고 쇼핑을 하려면 학교에서 ... 대학교 근처에는 학생들이 사는 작은 건물들과 marketsqure가 있습니다. marketsqure에는 한국음식점을 비롯한 다양한 식당들이 있기 때문에 학교 식당에 질릴 경우, 시도해 볼만 합니다. IGA 슈퍼마켓은 밤 늦게까지 운영하기 때문에 많은 학생들이 이용하지만, 가격이 비싼 편이라 장을 많이 볼 경우 버스를 타고 Robina town centre, Pacific fair의 대형 수퍼마켓(Coles, Woolworth 등)을 이용하는 것이 일반적입니다. 대학주변 환경은 단조롭고 한적하기 때문에 학교 근처에서 주말이나 휴일을 보낸다면 지루할 수도 있습니다. 많은 학생들이 쉬는날에는 Surfers paradise나 해변을 찾거나 robina town centre, pacific fair에 있는 영화관, sea world나 movie world같은 테마파크 등을 찾아갑니다. 그리고 Robina station에서 한시간 정도 기차를 타고 나가면 브리즈번에 갈 수 있습니다. 언급했던 바와 같이 학교는 호수를  ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 2  Bond와 그 동네를 생각하면 여유롭고 평화로웠던 분위기가 아직도 생생해요. 여기서 살고싶다라는 말을 입에 달고 살았었네요ㅜㅜ혹시 궁금한 것이 있으면 kang-ji-h@hanmail.net으로 메일주세요! 우리학교에 비하면 지루하다고 생각할 수 있는 학교 생활인데 저는 한국에서는 느낄 수 없었던 여유로움을 느낄 수 있어서 정말 좋은 한 학기를 보냈습니다. 학생수도 한국사람도 별로 없어서 다른 나라 친구들과 어울릴 수 있는 기회가 더 많았습니다. 정말 아름다운 캠퍼스에서 좋은 친구들과 좋은 한 학기를 다니고 주말에 잠깐씩 여행가기에도 좋은 곳에 위치해 있어서 주말마다 차를 다같이 렌트해서 12 명이서 로드트립을 간 적도 있고 그냥 지나가다 처음만난 친구와 3시간 동안 인생과 꿈에 대해서 얘기한 적도 있는 그런 한국에서는 하지 못 했을 소중한 경험들을 만들어준 곳이었습니다. 하루하루가 힐링이 되는 Bond 대학교에 대해 혹시나 궁금하신 점이 있으시다면 cjwogpwn@naver.com으로 언제든지 연락해 주세요!! 저는 개인적으로 시드니에서 6개월 먼저 머무르다가 교환학생에 합격되어 다시 호주에서 4~5개월 정도 더 있다가 오게 되었습니다. n처음에는 교통도 불편하고 말도 통하지 않아 호주의 장점이 보이지 않았었는데 시간이 지나니 이 곳만큼 사람이 살기에 좋은 곳도 없다는 것을 알게 되었습니다. n워낙 평소에 밤거리와 술 문화를 좋아했던 저에게는 오후 7시면 모두 집으로 귀가해 가족들과 시간을 보내는 이 곳 사람들의 생활방식이 이해가 안 갔었지만, 아침 일찍 일어나 조깅을 하고 모닝 커피와 함께 신문을 보는 이 곳이야말로 사람이 사람답게 살 수 있는 낙원이 아닌가 싶습니다. n살기 좋은 곳, 살고 싶은 곳이지만 교환학생이라는 짧은 기간 동안 그것을 느끼고 조금이라도 더 누려보려면 정말 active하게 지내야 하는 것 같습니다. 무엇보다도 자신감, 한국인의 긍지를 가지고 하나하나 배워나간다면 (개인적으로 학교 안에만 머무르지 말고 나가서 알바라도 하는 것을 추천합니다) 교환학생 지원... 호주 영어, 인종 차별부터 시작해서 학교 생활에 대해서 걱정만 하다가 파견 나갔는데, 막상 나가면 걱정하던 것보다 훨씬 재밌게 생활할 수 있습니다. Bond는 반이 교환학생이고, 그들 중 대다수가 미국에서 온 학생들이다보니 호주 액센트를 많이 접하지도 못했고, 또 호주 액센트가 강하더라도 며칠 듣다보면 금방 적응합니다. 인종차별은 요즘 호주 내에서 극도로 신경쓰고 있는 문제이기 때문에 오히려 더 신경써서 관리하고 있습니다. n저도 파견 나가기 전에 여기 있는 후기 정말 많이 읽어봤는데, 가서 겪어보기 전까지는 알 수가 없으니 마음 편하게 파견 기다리시면 될 듯 합니다. 다양한 경험 쌓고 즐겁게 놀고 온다는 마음으로 다녀오시길. 처음 한달은 힘들고, 한국인도 발견하기어렵고 사귄친구들은 많으나 왠지 외롭고 수업도 어리버리하고 그랬습니다. 처음 bond week이라 불리는 첫주(개강전 1주)에 많은 행사가 이우러지고 이때는 신입생들 교환학생들 등등 모두가 새롭게 시작하는때라서 친구를 사귀려면 이때 많이 사겨두어야 좋습니다. 학교 식당을 이용하면서 수월하게 여러 친구들을 만났고 건너서건너서 친구가 되고 인간관계도 많이 넓혔습니다. 한국에서 이미 학년이 3학년을 마치고 간터라 공부도 열심히 했습니다. 그래서 초반에만 열심히 시끄벅적하게 놀고 어느샌가부터는 도서관에 자주있었습니다. 그런데 도서관에서도 친구들을 사귈수있으니 그것도 역시 재미있더군요. 돌아올때는 시험 맨마지막날이 방빼기 하루전이어서 너무 정신없이 방을 빼고 나와서 좀 아쉬웠습니다. 조금더 며칠 친구들과 석별의 정을 나누고 싶었는데 정말 이부분은 아쉽습니다. 지금도 facebook등이나 가끔 문자로 친구들과 연락을 합니다. 본드에서의 추억과 생활... 본드대에 가게 된 학생들은 질문 사항이 있으면 주저없이 이메일로 질문을 주시길 바란다. 본드에서의 한학기는 정말 황금같은 시간이었습니다. 한국에서의 치열한 경쟁에서 벗어나 편한 마음으로 공부했고, 한국에서 하기 힘든 다양한 경험을 시도해 보았기 때문입니다. 또한 국제학생들이 많은 학교인 만큼, 여러 나라에서 온 친구들을 사귀면서 가까워질 수 있었습니다.n본드에서의 한학기는 엄청나게 빨리 지나가, 아쉬움이 많이 남습니다. 본드대학교로 가시는 분들은 하루하루를 소중하고 후회없이 보내시길 바랍니다. NaN 교환학생을 지원할 때 고민하고 걱정했던 것과는 달리, 막상 교환학생을 다녀오면 그 곳이 어떤 특정한 나라이고 학교인지는 크게 중요하지 않다고 생각합니다. 어느 곳엘 가더라도 열린 자세와 적극적인 태도만 있다면 평생 잊지 못할 소중한 경험을 만들 수 있을 것이라고 확신합니다. ^^ 본인은 교환학생 뿐만 아니라 운이 닿았는지 한국 정부 관계자로 일을 하고 인턴등등을 할 기회가 있어 그 뒤에도 계속 호주에 긴 시간 동안 남아 있었다. 학생회와 동아리 활동을 통해 정말 많은, 농담삼아 누군가가 나에게 거의 학교 학생의 반 정도를 안다고 했을 정도로 넓고 깊은 친구관계를 형성하였다. 연세대학교에서 매 학기마다 파견이 되는 것을 알고 있어 인사라도 하려 몇백명의 친구들에게 한국 연세대학교에서 이번 학기에 온 학생을 아냐고 물어 보면 아무도 보지도 듣지도 못했다고 하는 대답에 2학기 연속 실망을 한 기억이 난다.n다른 아시아계 교환학생들처럼 학교와 집만 왔다 갔다 하며 교환학생을 다녀왔다는 그 타이틀에 목 매이지 말고 자신을 위해 조금 더 나은 연세대학교의 위상을 떨칠 수 있는 교환학생이 되었으면 하는 당부 말씀을 드립니다. 나에게 Bond University 에서의 한학기는 평생 잊을 수 없는 추억이다. 지금 교환학생을 고민하고 있는 친구들이 있다면 자신있게 절대 후회 하지 않을 선택이라고 얘기해 주고 싶다. Bond University는 좋은 자연환경에서 다국적의 친구들을 만나고, 질높은 교육을 받을 수 있는 아주 좋은 기회이다.n위에 적은 내용 이외에도 더 알고 싶은 점이나 물어보고 싶은 것이 있다면 주저하지 말고 이메일을 보내기 바란다. epslz@hotmail.com 어느 나라나 바쁘고 활기찬 대도시의 분위기는 비슷하다. 해변가에 위치한 본드대학에서의 한학기는 정말로 특별한 경험이었다. 평생 언제 그런 여유로운 곳에서 생활을 해보겠는가. 오히려 대도시로 가지 않은 것이 다행이었다는 생각이 든다. 학교수업에 비치원피스와 조리를 신는 것이 정상이고 운동화에 청바지가 오히려 외면당하는 캠퍼스.. 교수와 학생사이의 상하관계가 적어 누구든 쉽게 다가가고 얘기 나눌 수 있는 강의실. 모두에게 특별한 한 학기가 되길 바라며... 교환학생을 준비하는 대부분의 학생들은 학교 결정에 많은 고민을 한다. 나도 많은 고민을 하였고, Bond를 결정하고 갔다 온 지금은 굉장히 만족하고 있다. 전교생의 반이 호주 외의 국가에서 온 학생들이기 때문에 그 어떤 학교에서보다도 다양한 문화와 사람들을 접할 수 있다. 본인이 좀 더 사교적으로 노력한다면 평생 간직할 좋은 인간관계를 만들 수 있을 것이다. 무엇보다 빡빡한 서울 생활에서 벗어나 휴양지에서 호주 특유의 여유로움을 느끼며 머리를 식히고 온 것이 꿈만 같다. 다른 어느 곳보다도 Bond에서는 새로운 문화를 접함과 동시에 내 삶도 돌아볼 수 있는 여유를 느낄 수 있다는 점에서 권하고 싶다. 이 글을 읽고 계신 분들은 아마도 대부분, 수 많은 나라와 학교들 중에 자신의 니즈를 충족시킬 수 있는 곳은 과연 어디인지 등 교환학교 선정에 고심하고 있는 분들일 거라 생각됩니다. 군대, 교환학생 등 짧지 않은 시간을 낯선 곳에서 보내면서 다시 한번 제가 느낀 점이라면, 새로운 곳에서의 생활에서 얼마나 만족을 느끼게 되느냐에 있어서 가장 중요한 점은 인간관계라는 어찌 보면 너무도 당연한 점이었습니다. 교환학생 프로그램을 통해 얻고자 하는 목표가 개인에 따라 다들 다를 것이기에 bond대학이 얼마나 매력적인 선택이 될 것인지에 대해서는 장담할 수 없으나, 어디를 가서든 만나게 될 많은 다양한 사람들과 좋은 관계를 맺어가고자 긍정적으로 노력한다면, 그 목표가 무엇이든 간에 분명 만족스러운 교환학생 생활을 하실 수 있을 것이라고 생각합니다.  ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      93dbal@naver.com 비치(해변)가 정말 좋으니 꼭 두번 세번 여러번 가시길 추천드립니다. NaN 처음 호주 Perth로 파견이 결정되었을 때, 사람들이 이름도 못 들어본 도시라고 의아해했습니다. 호주의 번화하고 발전한 동부의 시드니,멜버른,브리즈번 같은 도시도 아니고 이런 처음 들어보는 도시에서 너무 심심하지 않을까 했는데 너무나 행복한 한 학기였습니다. 제가 생각했을 때 Perth는 관광이나 놀이에 적합한 도시는 솔직히 아닙니다. 그러나 제 인생에 다시 없을 마음의 여유를 찾아준 도시였습니다. 어딜가나 공원이 있고, 한적한 거리에는 늘 새소리가 가득했습니다. 또 호주로 간다고 했을 때 사람들은 인종차별 등을 걱정했는데, 저는 한학기 동안 거주하면서 그런  ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                 저는 동호주, 뉴질랜드로 여행을 갔다가 그쪽이 너무 좋아서 교환학생 국가로 호주를 선택했습니다. 또 가 보지 않은 서호주를 가보고 싶어서 curtin을 선택했습니다.연대와는 교육 방식도 매우 다르고 학생들도 자유롭게 학교를 다녀서 매우 흥미로웠습니다.퍼스도 한국의 도시처럼 발달하지 않아서 5시만 되면 시티의 가게도 다 문을 닫아서 불편하긴 하지만 그만큼 여유롭고 평화로운 도시입니다. 바다나 섬같은 자연도 매우 아름답고 석양을 보면서 잠시 휴식을 만끽하는 것도 참 좋습니다. NaN 저는 진짜 정신없이 신청하느라 이 학교를 지원했었는지도 잘 모르고 있었는데요. 처음에 결과보고나서 퍼스가 어딘지 알았을 정도에요. 근데 생각해보면 그게 저한테는 정말 운이 좋았던 것 같아요. 혼자 가시는 것도 두려우실테지만 오히려 한국 학생들 여럿이서 같이 가게되면 그 안에서 문제 생기는 경우도 몇 번 봐서 이게 더 편하시다고 느끼실 수 있을거에요. 그리고 가서 저는 한국 친구와 얘기해본 적이 거의 없어요. 일부러 그런건 아니고 막상 한국학생들이 잘 없는 것 같더라고요. 물론 워킹비자로 해서 일하러는 많이 오는데 생활반경이 다르다보니까 학교 생활 중에서 만나본 한국인은 한 명 정도였습니다. 교환학생은 다양한 나라의 사람들 만나고 그 나라의 문화를 경험하는게 가장 큰 목적이잖아요. 그런 부분에서 보면 정말 적합한 학교였다고 생각합니다. 같이 가는 한국학생들없다고 너무 두려워하지 않으셨으면 좋겠습니다. -오리엔테이션 기간에 학교 안에 있는 Bankwest를 통해 수수료가 들지 않는 학생계좌를 만들 수 있습니다. n-호주에 가기전 기숙사를 신청할 당시 신청 기간이 우리학교 시험기간과 겹쳐서 약간 혼란스러워 했던 기억이 납니다. International office에서 권유하는 대로 COE를 받는 등의 절차를 밟고 기숙사를 신청할 시기가 오면 수시로 기숙사를 신청하는 홈페이지에 들어가보거나 accommodation office에 언제부터 인터넷 기숙사 신청이 가능한지 살짝 물어보는 것도 좋을 것 같습니다. 어느날 갑자기 사이트에 들어가보니 인터넷 신청이 열려있어서 당황하며 기숙사 신청을 했던 기억이 납니다.n-서호주는 퍼스 이외에도 그 주변으로 가 볼만한 곳들이 많은 지역입니다.nstudy free week나 학기 외의 시간이라도 이용해 여행해보실 것을 추천드립니다. n한학기라는 짧은 시간이었지만 제 인생에 있어서 많은 것을 느끼게 해준 아주 소중한 시간들이었습니다. 많... 평생 잊을 수 없는 교환학생이라는 소중한 기회를 주신 하나님께 감사드리며, 앞으로 Curtin University of Technology로 교환학생을 가시는 분들에게 인생에서 정말 귀중한 경험과 추억을 만들고 오실 수 있다는 것을 말씀드리고 싶습니다. 모두들 교환학생을 통해 큰 Vision을 가지고 돌아오시길 기도하겠습니다. 화이팅!! ^^ 호주 계절 기준으로 여기는 여름방학이 3달이고 겨울방학이 1달입니다. 여름방학을 이용하셔서 호주를 일주하신다면 평생에 남을 추억과 사람들을 만나실 수 있을겁니다. 기독교인의 경우에는 교회를 정하는 것이 큰 문제중의 하나라고 생각합니다. 퍼스에는 호주교회 뿐아니라 여러개의 한인교회가 있습니다.캠퍼스내에 chapel 이 있어 상담을 받을 수 있고 원하는 교회에 대한 정보를 얻을 수 있습니다. 호주는 땅이 넓은 데다 한국처럼 대중교통시설이 발달되어 있지 않아, 개인 차를 소유하는 것이 편리합니다. 2학기 파견하는 분이라면, 가자마자 중고차를 사는 것도 좋은 듯 합니다. 물론 보험문제와 갈 때 다시 되파는 등의 문제가 있겠지만.--;아니면 차가 있는 친구들을 많이 사귀는 것도 좋은 방법이 되겠죠. 저녁에 친구들과 해변에 가서 지는 석양을 보며 밥을 먹던 것이나, 영화관에 갔던 것들이 정말 좋은 추억인 거 같습니다. 내가 차가 있었으면 좀 더 많은 곳을 가 볼 수 있었을텐데 하는 아쉬움이 남습니다.특히 여행을 갈때는 친구들과 같이 차를 렌트해서 갈 것을 권유합니다. 그게 비용도 저렴하고 재밌게 여행을 즐길 수 있는 방법입니다. 저는 개인적으로 차만 제공해주는 tour로 갔었는데, 비용만 비쌀 뿐 별로였던거 같습니다. 아무튼 호주는 차가 `필수`인 나라입니다. 그 점 꼭 참고하시길.. 기회가 되지 않아 1개학기 밖에 파견나가지 못한 아쉬움도 너무 크지만 4개월이라는 시간동안 많이보고 많이 느끼고 온것 같습니다. 다양한 사람, 인종, 문화를 접할 수 있어 너무 소중한 경험이었고 이런 기회를 주신 교환학생상담실과 국제교육교류부에 감사드립니다. 퍼스는 호주의 1/3을 차지하는 서호주의 수도임에도 불구, 그 규모가 매우 큰 편이지만 생활 스타일은 그다지 복잡하지 않다. 오히려 한국의 시골을 연상시킬 정도이니, 대충 짐작할 수 있으리라.(물론 여타 편의시설이나 빌딩 등만 본다면 한국의 시골과는 비교가 불가하겠지만 말이다.)하지만 조용한 곳에서 아름다운 자연 환경을 만끽하며 여유를 누리고 싶은 분이라면 정말 제 격이라고 생각한다. 그렇다고 도시의 북적거림이 좋은 분이라도 크게 실망할 필요는 없다. 나이트클럽 혹은 재즈클럽 등과 같은 그 나름의 즐길 수 있는 entertainment 문화도 마련되어 있으니 말이다. 내 경우도 전자보다는 후자에 가까운 터라 퍼스가 쏘옥~~ 마음에 들었던 것은 아니지만, '여유'에 대해 다시 한 번 더 생각해보며 '어떻게' 살아가야 할 지 생각할 수 있는 좋은 시간이었음은 분명히 말할 수 있다. 특히 2학기를 가시는 경우, 긴 여름방학을 이용해 호주를 배낭 여행하는 것도 좋겠다. 혹은 다양한 ... 퍼스의 물가에 대해서 말씀 드리면, 서울에 비해서 결코 비싸지 않으며 오히려 더 싸다는 느낌을 받았습니다. 그래서 한 달 동안의 생활비는 쓰기 나름이지만 약 1000달러 정도 잡으시면 되실겁니다. 나가시기 전에 꼭 준비해야 할 것은 앞에서도 언급했듯이 썬글라스와 호주의 콘센트는 한국과 다르므로 전자제품을 가져가실 경우 어뎁터는 그곳에서 구할 수 있으므로 멀티플러그를 가져가면 편리합니다. 그리고 전기밥솥도 가능하면 가져갈 것을 권합니다. 그리고 혹시 호주에서 운전할 일이 있을 수도 있으므로 국제운전면허증도 발급 받아 가시기 바랍니다. 저의 경우 저보다 학 학기 먼저 온 형의 차를 구입해서 약 6개월 동안 유용하게 쓸 수 있었고 다른 교환학생들과 여행을 갈 때 랜트카도 빌릴 수 있었습니다.생활하는데 필요한 가전제품이 있을 수 있는데, 학교 곳곳에 going home sale이라고 중고 물품을 광고 붙어져 있으므로 이 광고를 통해 각종 살림을 장만하는게 가장 저렴할 듯 싶습니다. ... 호주에 가서 놀란 것은 working hours인데 보통 상점이나 공공기관 등은 오전 9시부터 5시까지입니다. Shopping center 등은 목요일, 시내는 금요일이 오후 9시까지 열기 때문에 꽤나 편리합니다. 어쨌거나 호주에서는 평일 저녁에는 매우 심심할 수도 있습니다만 좋은 친구들을 많이 사귀고 학업에 열중하면 매우 바쁠 것입니다. Perth 근처에도 beach나 관광코스가 많기 때문에 주말을 이용해 다녀오기도 편리합니다. 학기 중에는 중간 고사 다음 주에 study free week가 있어서 여행을 다니기에 좋은 기회입니다. Tour를 따라가는 것도 (일반적으로 생각하던 tour와 상당히 달랐고 무척 재미있습니다.) 좋은  ...

# %%
df_column.isnull().sum()
# Out:
# 대학코드           0
# 대학명            0
# gen_info       0
# env_info       0
# food_info      0
# study_info     0
# office_info    0
# facil_info     0
# mhct_info      0
# help_info      0
# etc_info       0
# dtype: int64

# %%
import re
# removing junks from the string data
def remove_junk(str_data):
    str_data = str_data.replace("\\\\n", "") #slash n 이 엔터, 쓸데 없는 걸 없애는 거
    str_data = str_data.replace("\\n", "")
    str_data = str_data.replace("\n", "")
    str_data = str_data.replace("\\", "")
    str_data = str_data.replace("\\t", "")
    str_data = str_data.replace("NaN", "")

    # 한글, -english 빼고 전부 날리기
    # regex, regular expression, 특정 글자수 규칙 지정, 말고는 다 날림
    str_data = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', str_data)
    # replace multiple spaces into single space
    str_data = ' '.join(str_data.split()) #멀티플 스페이스를 싱글로 바꿈
    return str_data

# %%
all_data = ['gen_info', 'env_info', 'food_info', 'study_info', 'office_info', 'facil_info', 'mhct_info', 'help_info', 'etc_info']
univ_code = "MX000004","CH000004"

# %%
gen_data = 'gen_info'
univ_code = "MX000004"

# %%
def access_univ_info(dataframe, column, univ_code):
    df_row = dataframe.loc[dataframe["대학코드"] == univ_code]
    str_univ_info = df_row[column].to_string(index=False).lstrip()
    str_univ_info = remove_junk(str_univ_info)
    return str_univ_info

# %%
str_example = access_univ_info(df_specific, gen_data, univ_code)
str_example[:500]
# Out:
# '일단 저는 학기에 갔는데 몬테레이 지역이 미국 텍사스 국경선 바로 밑에 위치 현지인들 사이에서 날씨가 매우 안 좋다는 말이 많았어요 우중충하다기 보다는 날씨를 감 잡을 수 없다는 말이 많았는데 정말 월 초에 하루 반팔을 입어도 덥다가 다음날 패딩을 입어야만 하는 날씨의 변동이 있었습니다 하지만 그때 외로는 전반적으로 따뜻하거나 덥고 춥더라도 한국의 겨울만큼 춥지는 않습니다 학교 주변에는 산이 많아서 주말에 등산을 하는 프로그램도 많았는데 저는 한번 다녀왔습니다 비가 거의 안 오는 지역이기는 하나 한번 오면 정전이 될 정도로 왔었던 기억이 있네요 하지만 특별히 불편함이나 위험함을 느끼지는 못했습니다 대학교는 우선 굉장히 자연적 친화적입니다 조그마한 쉼터도 많고 숲풀 연못 정원 등이 곳곳에 있으며 크기는 작지만 저에게는 다니기 딱 적당했습니다 가을학기에 날씨는 정말 아 예 예상 불가이고 낮엔 도 저녁에 도 비도 많이 옵니다 더운 나라라고만 생각하시면 큰코다칩니다 저는 많이 다쳤습니다 학'

# %%
# collecting all column values into one string 여러개의 카테고리별 후기를 하나로 대학으로
def column_to_string(dataframe, column_name: str):
    str_corpus = dataframe[column_name].to_string(index=False).lstrip()
    str_corpus = remove_junk(str_corpus)
    return str_corpus

# %%
# collecting all column values into one string
gen_corpus = str_example
print("글자수:", len(gen_corpus))
gen_corpus[:1000]
# Out:
# 글자수: 2353
# '일단 저는 학기에 갔는데 몬테레이 지역이 미국 텍사스 국경선 바로 밑에 위치 현지인들 사이에서 날씨가 매우 안 좋다는 말이 많았어요 우중충하다기 보다는 날씨를 감 잡을 수 없다는 말이 많았는데 정말 월 초에 하루 반팔을 입어도 덥다가 다음날 패딩을 입어야만 하는 날씨의 변동이 있었습니다 하지만 그때 외로는 전반적으로 따뜻하거나 덥고 춥더라도 한국의 겨울만큼 춥지는 않습니다 학교 주변에는 산이 많아서 주말에 등산을 하는 프로그램도 많았는데 저는 한번 다녀왔습니다 비가 거의 안 오는 지역이기는 하나 한번 오면 정전이 될 정도로 왔었던 기억이 있네요 하지만 특별히 불편함이나 위험함을 느끼지는 못했습니다 대학교는 우선 굉장히 자연적 친화적입니다 조그마한 쉼터도 많고 숲풀 연못 정원 등이 곳곳에 있으며 크기는 작지만 저에게는 다니기 딱 적당했습니다 가을학기에 날씨는 정말 아 예 예상 불가이고 낮엔 도 저녁에 도 비도 많이 옵니다 더운 나라라고만 생각하시면 큰코다칩니다 저는 많이 다쳤습니다 학교가 위치한 몬테레이 도시는 미국 동부 바로 밑이라 차로 텍사스까지 시간이면 도착할 수 있는 곳입니다 멕시코에서는 두 번째로 큰 지역이고 공업 및 상업화를 크게 이뤘으며 물가도 멕시코 중에서 거의 가장 비쌉니다 멕시코 다른 지역과 비교했을 때는 거의 두 배 이지만 우리나라보다는 아주 조금 싼 편입니다 물품에 따라서도 다릅니다 몬테레이 공과대학 Tec 은 사립 중에서 가장 좋은 학교로 꼽힙니다 남미의 서울대 라고 불리는 국립 UNAM이 있긴 하지만 멕시코 시티에 캠퍼스가 하나 뿐입니다 반면 Tec은 전 국에 캠퍼스가 있으며 특히 몬테레이 캠퍼스는 그 중 으뜸이지요 산을 배경으로 둔 캠퍼스는 경치도 너무 좋고 주말엔 그 산으로 등산도 갈 수 있습니다 학교는 우리 학교보다 조금 작지만 정말 어마어마하게 큰 체육시설 테니스 코트 축구장 요가원 농구장 암벽타기 시설 등 과 스태디움을 포함하면 우리학교만 하단 생각이 듭니다 저는 월에 있었기 때문에 날씨는 너무나 좋았어요 좀 더운편이지만 늘 햇'

# %% [markdown]
# ## Tokenizing with soynlp

# %%
# https://github.com/lovit/soynlp 문장을 쪼개는 방식. 쪼개진 거의 예시가 
from soynlp.tokenizer import RegexTokenizer

tokenizer = RegexTokenizer()
tokenizer

# %%
tokenized_gen = tokenizer.tokenize(gen_corpus)
tokenized_gen[:30]
# Out:
# ['일단',
#  '저는',
#  '학기에',
#  '갔는데',
#  '몬테레이',
#  '지역이',
#  '미국',
#  '텍사스',
#  '국경선',
#  '바로',
#  '밑에',
#  '위치',
#  '현지인들',
#  '사이에서',
#  '날씨가',
#  '매우',
#  '안',
#  '좋다는',
#  '말이',
#  '많았어요',
#  '우중충하다기',
#  '보다는',
#  '날씨를',
#  '감',
#  '잡을',
#  '수',
#  '없다는',
#  '말이',
#  '많았는데',
#  '정말']

# %%
from collections import Counter

# %%
print(len(tokenized_gen))
# Out:
# 591

# %%
tokenized_gen_counted = Counter(tokenized_gen)
print("no. gen words:", len(tokenized_gen_counted))
common_gen_words = tokenized_gen_counted.most_common(10)
common_gen_words
# Out:
# no. gen words: 453
# [('수', 9),
#  ('멕시코', 9),
#  ('있습니다', 8),
#  ('몬테레이', 7),
#  ('많이', 6),
#  ('저는', 5),
#  ('월', 5),
#  ('날씨는', 5),
#  ('도', 5),
#  ('있는', 5)]

# %%
min(tokenized_gen_counted, key=tokenized_gen_counted.get)
# Out:
# '아르헨티나의'

# %%
### WORD2VEC

# %%
stopwords_kr = ['으로', '에서', '있는', '하는', '하고', '있습니다', '그리고','편입니다','아주','곳에','않습니다','좋습니다','않았습니다',
                '입니다', '어느', '하는데', '대체', '있으면', '최근', '좋은','은','있는데','주로',
                '라고', '봅니다', '해야', '있다고', '이라는', '합니다', '조금','굉장히','있으며','것이','갈','자주',
                '경우', '가능한', '하지만', '또한', '처럼', '있어', '보다', '꽤', '상당히',
                '되어', '이미', '그러나', '이루어지고', '이라', '위해', '되면', '와','를', '가지고',
                '이런', '까지', '하여', '우리', '어떤', '에게', '있지만', '해주는', '바로', '내내', '것을', '크게',
                '정도', '또는', '부터', '대해', '모든', '하기', '어떻게', '같습니다', 
                '이라고', '에는', '때문', '되고', '됩니다', '통해', '있을', '결국', '않은','훨씬','같아요','정도의','같습니다','버스를',
                '이를', '특히', '있도록', '대한', '가장', '이나', '에서는', '있고', 
                '같은', '에서도', '아닌', '다른', '따라', '되어야', '한다고', '다만', '볼','도','다'
                '이러한','해서', '관련', '생각', '하지', '않을까요', '약간', '되는', 
                '에선', '라는', '물론', '않을까', '하면', '아니라', '말씀', '에도', 
                '아니라', '부분', '분야', '많은', '여러', '향후', '기반', '행차', '할', '있어서',
                '그러면서', '되지만', '현재', '제가', '저는', '너무', '작은','ity','의','거의','정도로',
                '정말','그들','여타','없으므','완전','몇몇','만약','게다','이후','우선',
                '시쯤','후반','더욱','원하는','많을','몇개','분명','두어개', '하므', '수밖',
                '이','있','하','것','들','되','수','이','보','않','없','나','사람','주','아니','등','같',
                '우리','때','년','가','한','지','대하','오','말','일','그렇','위하','때문','그',
                '그것','두','말하','알','받','못하','일','에','4','10','5', '8','6','9','7','nn','대부분', '오는','꼭'
                '그런','또','문제','더','사회', '는','많이','n','1','2','3','있다','분',
                '많','좋','크','따르','중','나오','가지','씨','시키','만들','지금','생각하',
                '그러','속','하나','살','모르','적','월','데','자신','안','어떤','내','경우',
                '명','그녀','다시','이런','앞','보이','번','다른','어떻','여자','개','전','들',
                '사실','이렇','점','싶','말','정도','좀','원','잘','통하','소리','놓','큰','매우','때문에']

# %%
stops = open('/Users/jupiter/Desktop/Exchange_proj/stopwords_kr.txt', encoding='utf').read()

# %%
keywords = []
for n in tokenized_gen: 
    if n not in stopwords_kr: 
        keywords.append(n)

# %%
common_keywords = Counter(keywords)
common_key_words = common_keywords.most_common(30)
common_key_words
# Out:
# [('멕시코', 9),
#  ('몬테레이', 7),
#  ('날씨는', 5),
#  ('산이', 4),
#  ('캠퍼스는', 4),
#  ('Monterrey', 4),
#  ('산을', 3),
#  ('TEC', 3),
#  ('위치해', 3),
#  ('캠퍼스를', 3),
#  ('ITESM', 3),
#  ('학기에', 2),
#  ('미국', 2),
#  ('말이', 2),
#  ('많았는데', 2),
#  ('입어도', 2),
#  ('덥고', 2),
#  ('한번', 2),
#  ('많고', 2),
#  ('등이', 2),
#  ('작지만', 2),
#  ('차로', 2),
#  ('시간이면', 2),
#  ('중에서', 2),
#  ('때는', 2),
#  ('Tec', 2),
#  ('캠퍼스가', 2),
#  ('체육시설', 2),
#  ('올', 2),
#  ('공과대학교', 2)]

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 워드클라우드를 위한 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null

# 워드클라우드를 위한 나눔고딕 경로 설정
import matplotlib.font_manager as fm
fontpath = './font/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
backgroundcolor = "white"
width=800
height=600
wordcloud = WordCloud(font_path = fontpath,
                        stopwords = set(stopwords_kr), 
                        background_color = backgroundcolor, 
                        max_words= 200,
                        max_font_size= 150,
                        width = width, 
                        height = height)

# %%
wordcloud.generate_from_frequencies(frequencies = common_keywords) # mecab으로 추출한 명사로 워드클라우드를 그린다.
plt.figure(figsize = (15 , 10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
#이래서 전체 스탑워드 뽑은 다음에 각 학교에서 유니크한 거만 정리하는 식으로 하는 거..? 
#아니면 그냥 좋은 거에 대한 대학 0이랑 1 나눠서 그 대학들 키워드만 모아서 알아보기 그 때 그 때 스탑워드 처리.

# %%
word_list, frequency_list = map(list, zip(*common_gen_words))
word_list[:10]
# Out:
# ['있습니다', '수', '있는', '때문에', '는', '많이', '매우', '학교', '큰', '분']

# %%
# https://github.com/lovit/soynlp
from soynlp.noun import LRNounExtractor

# %%
from soynlp.noun import LRNounExtractor
noun_extractor = LRNounExtractor()
nouns = noun_extractor.train_extract(keywords)
# Out:
# [Noun Extractor] used default noun predictor; Sejong corpus predictor
# [Noun Extractor] used noun_predictor_sejong
# [Noun Extractor] All 2398 r features was loaded
# [Noun Extractor] scanning was done (L,R) has (32191, 17129) tokens
# [Noun Extractor] building L-R graph was done000 / 860976 sents
# [Noun Extractor] 5490 nouns are extracted

# %%
nouns_counted = Counter(nouns)
print("no. gen words:", len(nouns_counted))
common_nouns = nouns_counted.most_common(100)
common_nouns
# Out:
# no. gen words: 5490
# [('위치',
#   NounScore_v1(frequency=12933, score=0.9765788869755492, known_r_ratio=0.8816473746015769)),
#  ('캠퍼스',
#   NounScore_v1(frequency=12581, score=0.5661491689446561, known_r_ratio=0.9409656335652541)),
#  ('학교',
#   NounScore_v1(frequency=10901, score=0.6434451175213675, known_r_ratio=0.850909090909091)),
#  ('도시',
#   NounScore_v1(frequency=7053, score=0.8971600936736356, known_r_ratio=0.6836829404121032)),
#  ('겨울',
#   NounScore_v1(frequency=6931, score=0.6987589767525679, known_r_ratio=0.866625019522099)),
#  ('시간',
#   NounScore_v1(frequency=5015, score=0.7587921471727341, known_r_ratio=0.678046218487395)),
#  ('건물',
#   NounScore_v1(frequency=4919, score=0.5452611554643406, known_r_ratio=0.6264866602378656)),
#  ('여름',
#   NounScore_v1(frequency=4184, score=0.7111721313559322, known_r_ratio=0.8500128633907899)),
#  ('한국',
#   NounScore_v1(frequency=4097, score=0.9879323552180302, known_r_ratio=0.9212367411419544)),
#  ('생각',
#   NounScore_v1(frequency=3915, score=0.9325822089804185, known_r_ratio=0.7423558897243108)),
#  ('수업',
#   NounScore_v1(frequency=3538, score=0.5637023570673244, known_r_ratio=0.9092948717948718)),
#  ('미국',
#   NounScore_v1(frequency=3525, score=0.8987620616287603, known_r_ratio=0.8561557788944724)),
#  ('거리',
#   NounScore_v1(frequency=3174, score=0.8112627017793598, known_r_ratio=0.9114498864742134)),
#  ('날씨가', NounScore_v1(frequency=3010, score=0.93776, known_r_ratio=1.0)),
#  ('비슷',
#   NounScore_v1(frequency=2469, score=0.9934591760355034, known_r_ratio=0.8217179902755267)),
#  ('버스',
#   NounScore_v1(frequency=2382, score=0.7971222193353472, known_r_ratio=0.8719704952581665)),
#  ('가을',
#   NounScore_v1(frequency=2194, score=0.7091269455782314, known_r_ratio=0.49)),
#  ('학생들',
#   NounScore_v1(frequency=2186, score=0.91134358428246, known_r_ratio=0.9837535014005602)),
#  ('따뜻',
#   NounScore_v1(frequency=2154, score=0.9937161684045879, known_r_ratio=0.8666967916854948)),
#  ('연세대학교',
#   NounScore_v1(frequency=2145, score=0.9645463635280096, known_r_ratio=0.9893867924528302)),
#  ('이용',
#   NounScore_v1(frequency=2091, score=0.9778174887417217, known_r_ratio=0.7319437712069802)),
#  ('규모',
#   NounScore_v1(frequency=1992, score=0.5130774710341094, known_r_ratio=0.9433094994892748)),
#  ('여행',
#   NounScore_v1(frequency=1870, score=0.6593331526717556, known_r_ratio=0.7696827262044653)),
#  ('기숙사',
#   NounScore_v1(frequency=1825, score=0.8190401665611146, known_r_ratio=0.9148319814600232)),
#  ('처음',
#   NounScore_v1(frequency=1791, score=0.9821587548076922, known_r_ratio=0.7923809523809524)),
#  ('도착',
#   NounScore_v1(frequency=1744, score=0.9788096696832578, known_r_ratio=0.7731778425655976)),
#  ('지역',
#   NounScore_v1(frequency=1722, score=0.7916166652142338, known_r_ratio=0.8809980806142035)),
#  ('우리나라',
#   NounScore_v1(frequency=1664, score=0.9827770250403878, known_r_ratio=0.9911929543634908)),
#  ('지리적',
#   NounScore_v1(frequency=1634, score=0.9965687102040817, known_r_ratio=0.7401812688821753)),
#  ('하나',
#   NounScore_v1(frequency=1612, score=0.8609099832285115, known_r_ratio=0.7265803503427266)),
#  ('이동',
#   NounScore_v1(frequency=1585, score=0.9134574963369962, known_r_ratio=0.6290322580645161)),
#  ('학기',
#   NounScore_v1(frequency=1568, score=0.6538518200000002, known_r_ratio=0.23148148148148148)),
#  ('비교',
#   NounScore_v1(frequency=1558, score=0.9306042123385942, known_r_ratio=0.4511326860841424)),
#  ('공항',
#   NounScore_v1(frequency=1515, score=0.8329535410334349, known_r_ratio=0.9406719085060757)),
#  ('교환학생',
#   NounScore_v1(frequency=1507, score=0.5199650769230768, known_r_ratio=0.7876221498371335)),
#  ('기차',
#   NounScore_v1(frequency=1502, score=0.9058158123003194, known_r_ratio=0.8072211476466795)),
#  ('경우',
#   NounScore_v1(frequency=1465, score=0.5487573674321503, known_r_ratio=0.9815573770491803)),
#  ('시내',
#   NounScore_v1(frequency=1451, score=0.9696754637985309, known_r_ratio=0.9041745730550285)),
#  ('바람',
#   NounScore_v1(frequency=1362, score=0.8625022454183269, known_r_ratio=0.9147230320699709)),
#  ('연대',
#   NounScore_v1(frequency=1359, score=0.9735997774957696, known_r_ratio=0.9680589680589681)),
#  ('자전거',
#   NounScore_v1(frequency=1357, score=0.9455296627534684, known_r_ratio=0.9780793319415448)),
#  ('캘리포니아',
#   NounScore_v1(frequency=1346, score=0.797261172989378, known_r_ratio=0.8481338481338482)),
#  ('생활',
#   NounScore_v1(frequency=1345, score=0.8276829025460932, known_r_ratio=0.856390977443609)),
#  ('대부분',
#   NounScore_v1(frequency=1306, score=0.925560341853035, known_r_ratio=0.9586523736600306)),
#  ('건물들이', NounScore_v1(frequency=1298, score=0.999185, known_r_ratio=0.5)),
#  ('주변',
#   NounScore_v1(frequency=1286, score=0.8523448197424893, known_r_ratio=0.9329329329329329)),
#  ('느낌',
#   NounScore_v1(frequency=1277, score=0.6377613748870823, known_r_ratio=0.884185303514377)),
#  ('기온',
#   NounScore_v1(frequency=1270, score=0.5423112887931034, known_r_ratio=0.934730056406124)),
#  ('유명',
#   NounScore_v1(frequency=1261, score=0.9966207490272375, known_r_ratio=0.8460905349794239)),
#  ('수도',
#   NounScore_v1(frequency=1238, score=0.6972059767441862, known_r_ratio=0.3087971274685817)),
#  ('월부',
#   NounScore_v1(frequency=1205, score=0.99883, known_r_ratio=0.0016611295681063123)),
#  ('크지',
#   NounScore_v1(frequency=1202, score=1.0, known_r_ratio=0.07692307692307693)),
#  ('사람들',
#   NounScore_v1(frequency=1153, score=0.9065055337915233, known_r_ratio=0.9909194097616345)),
#  ('건물들',
#   NounScore_v1(frequency=1146, score=0.9402459501084598, known_r_ratio=0.986096256684492)),
#  ('건조',
#   NounScore_v1(frequency=1128, score=0.9878867324516787, known_r_ratio=0.870682019486271)),
#  ('아름',
#   NounScore_v1(frequency=1118, score=0.9897176355382621, known_r_ratio=0.6908602150537635)),
#  ('서울',
#   NounScore_v1(frequency=1115, score=0.9616968742514971, known_r_ratio=0.918423464711274)),
#  ('시작',
#   NounScore_v1(frequency=1114, score=0.9723473329452852, known_r_ratio=0.7990697674418604)),
#  ('개의',
#   NounScore_v1(frequency=1077, score=0.817389, known_r_ratio=0.8571428571428571)),
#  ('모두',
#   NounScore_v1(frequency=1063, score=0.8809403623188408, known_r_ratio=0.69)),
#  ('분들',
#   NounScore_v1(frequency=1039, score=0.9362533558178752, known_r_ratio=0.9801652892561984)),
#  ('필요',
#   NounScore_v1(frequency=1039, score=0.6280563013293943, known_r_ratio=0.7148891235480465)),
#  ('불편',
#   NounScore_v1(frequency=1037, score=0.7876174795454546, known_r_ratio=0.42759961127308066)),
#  ('뉴욕',
#   NounScore_v1(frequency=1032, score=0.7387478000000001, known_r_ratio=0.5682951146560319)),
#  ('주의',
#   NounScore_v1(frequency=1001, score=0.9949450612244897, known_r_ratio=0.47115384615384615)),
#  ('캐나다',
#   NounScore_v1(frequency=992, score=0.8691484393939393, known_r_ratio=0.88)),
#  ('편리',
#   NounScore_v1(frequency=990, score=0.9888960601265826, known_r_ratio=0.6332665330661322)),
#  ('중심',
#   NounScore_v1(frequency=989, score=0.8730115236985236, known_r_ratio=0.5547413793103448)),
#  ('기억',
#   NounScore_v1(frequency=969, score=0.9118459475982533, known_r_ratio=0.715625)),
#  ('지하철',
#   NounScore_v1(frequency=966, score=0.7757743031496063, known_r_ratio=0.737300435413643)),
#  ('근처',
#   NounScore_v1(frequency=962, score=0.9270182708333335, known_r_ratio=0.9758576874205845)),
#  ('쌀쌀',
#   NounScore_v1(frequency=960, score=0.991605416558862, known_r_ratio=0.7952674897119342)),
#  ('파견',
#   NounScore_v1(frequency=952, score=0.8271006037383178, known_r_ratio=0.6128293241695304)),
#  ('북쪽',
#   NounScore_v1(frequency=931, score=0.9655200340760155, known_r_ratio=0.9707379134860051)),
#  ('유럽',
#   NounScore_v1(frequency=928, score=0.921136941964286, known_r_ratio=0.7804878048780488)),
#  ('네덜란드',
#   NounScore_v1(frequency=917, score=0.9493802062780269, known_r_ratio=0.9389473684210526)),
#  ('남쪽',
#   NounScore_v1(frequency=914, score=0.9565127327823693, known_r_ratio=0.9552631578947368)),
#  ('추위',
#   NounScore_v1(frequency=886, score=0.7390810459627332, known_r_ratio=0.9698795180722891)),
#  ('자리',
#   NounScore_v1(frequency=857, score=0.9270880811518323, known_r_ratio=0.9807445442875481)),
#  ('전체',
#   NounScore_v1(frequency=852, score=0.9607052618110239, known_r_ratio=0.5582417582417583)),
#  ('연세대',
#   NounScore_v1(frequency=847, score=0.9661756821589205, known_r_ratio=0.232)),
#  ('사이',
#   NounScore_v1(frequency=829, score=0.9994153847283409, known_r_ratio=0.8234582829504232)),
#  ('강의실',
#   NounScore_v1(frequency=826, score=0.7190315260223048, known_r_ratio=0.9212328767123288)),
#  ('일교차',
#   NounScore_v1(frequency=786, score=0.8956371368970014, known_r_ratio=0.9961038961038962)),
#  ('영하',
#   NounScore_v1(frequency=760, score=0.9990234173228345, known_r_ratio=0.9548872180451128)),
#  ('엄청',
#   NounScore_v1(frequency=759, score=0.8309696692307693, known_r_ratio=0.5220883534136547)),
#  ('독일',
#   NounScore_v1(frequency=756, score=0.7957890214477212, known_r_ratio=0.9053398058252428)),
#  ('햇빛',
#   NounScore_v1(frequency=754, score=0.7828931765578634, known_r_ratio=0.9897209985315712)),
#  ('추천',
#   NounScore_v1(frequency=741, score=0.7751527205882353, known_r_ratio=0.19596541786743515)),
#  ('분정',
#   NounScore_v1(frequency=741, score=0.505755, known_r_ratio=0.7678812415654521)),
#  ('계속',
#   NounScore_v1(frequency=729, score=0.9831730288065843, known_r_ratio=0.6675824175824175)),
#  ('실제',
#   NounScore_v1(frequency=728, score=0.9960647791741473, known_r_ratio=0.9570446735395189)),
#  ('내에서', NounScore_v1(frequency=725, score=1.0, known_r_ratio=1.0)),
#  ('다운타운',
#   NounScore_v1(frequency=723, score=0.9330609857904084, known_r_ratio=0.9842657342657343)),
#  ('좋아',
#   NounScore_v1(frequency=707, score=0.776902558510638, known_r_ratio=0.7430830039525692)),
#  ('나라',
#   NounScore_v1(frequency=699, score=0.8686538757515031, known_r_ratio=0.8316666666666667)),
#  ('평지',
#   NounScore_v1(frequency=698, score=0.7358562372322901, known_r_ratio=0.9324116743471582)),
#  ('주도',
#   NounScore_v1(frequency=692, score=0.7077378653846154, known_r_ratio=0.3623693379790941)),
#  ('바다',
#   NounScore_v1(frequency=691, score=0.8291031607142857, known_r_ratio=0.717948717948718)),
#  ('도서관',
#   NounScore_v1(frequency=686, score=0.6763739525222552, known_r_ratio=0.903485254691689))]

# %%
noun_extractor.lrgraph.get_r('날씨')
# Out:
# [('가', 3008),
#  ('는', 2125),
#  ('', 659),
#  ('를', 620),
#  ('에', 265),
#  ('입니다', 257),
#  ('와', 201),
#  ('도', 178),
#  ('로', 173),
#  ('였습니다', 172)]

# %%
noun_extractor.lrgraph.get_l('학교')
# Out:
# [('연세대', 454),
#  ('대', 348),
#  ('우리', 120),
#  ('고등', 59),
#  ('주립대', 25),
#  ('교환', 11),
#  ('국립대', 8),
#  ('홍콩대', 8),
#  ('서울대', 7),
#  ('사립', 6)]

# %%
print((nouns['환경']))
# Out:
# NounScore_v1(frequency=326, score=0.7002796900826446, known_r_ratio=0.8373702422145328)

# %%
print((nouns['학교']))
# Out:
# NounScore_v1(frequency=10901, score=0.6434451175213675, known_r_ratio=0.850909090909091)

# %%
from soynlp.noun import LRNounExtractor_v2

noun_extractor = LRNounExtractor_v2(verbose=True)
#noun_extractor.train(sents)
#nouns = noun_extractor.extract()
nouns_eo = noun_extractor.train_extract(keywords)
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 109816 from 860976 sents. mem=0.600 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=860975, mem=0.667 Gb
# [Noun Extractor] batch prediction was completed for 31328 words
# [Noun Extractor] checked compounds. discovered 8893 compounds
# [Noun Extractor] postprocessing detaching_features : 18898 -> 15903
# [Noun Extractor] postprocessing ignore_features : 15903 -> 15764
# [Noun Extractor] postprocessing ignore_NJ : 15764 -> 15434
# [Noun Extractor] 15434 nouns (8893 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.685 Gb
# [Noun Extractor] 68.45 % eojeols are covered

# %%
list(noun_extractor._compounds_components.items())[:50]
# Out:
# [('학교배정인터뷰순서', ('학교', '배정', '인터뷰', '순서')),
#  ('전문고등교육기관', ('전문', '고등교육기관')),
#  ('교환학생보고서', ('교환학생', '보고서')),
#  ('상해박람회개최준비', ('상해', '박람회', '개최', '준비')),
#  ('경영전문사립대학교', ('경영', '전문', '사립대학교')),
#  ('프랑크푸르트국제공항', ('프랑크푸르트', '국제공항')),
#  ('슈투트가르트공항', ('슈투트가르트', '공항')),
#  ('스투트가르트공항', ('스투트가르트', '공항')),
#  ('저희학교캠퍼스', ('저희', '학교캠퍼스')),
#  ('아오야마가쿠인대학교', ('아오야마가쿠인', '대학교')),
#  ('우에가하라캠퍼스', ('우에가하라', '캠퍼스')),
#  ('후쿠오카국제공항', ('후쿠오카', '국제공항')),
#  ('후쿠오카의과대학', ('후쿠오카', '의과대학')),
#  ('스즈카케다이캠퍼스', ('스즈카케다이', '캠퍼스')),
#  ('코마바토다이마에역', ('코마바', '토다이마에역')),
#  ('유로라인버스정류장', ('유로라인', '버스정류장')),
#  ('메인게스트하우스', ('메인', '게스트하우스')),
#  ('맨체스터유나이티드', ('맨체스터', '유나이티드')),
#  ('위치상트페테르부르크', ('위치', '상트페테르부르크')),
#  ('경험보고서연세대학교', ('경험보고서', '연세대학교')),
#  ('영국공립종합대학', ('영국', '공립', '종합대학')),
#  ('종합대학교스코틀랜드', ('종합대학교', '스코틀랜드')),
#  ('빨간색지하철라인', ('빨간색', '지하철', '라인')),
#  ('북부버지니아지방', ('북부', '버지니아', '지방')),
#  ('포틀랜드국제공항', ('포틀랜드', '국제공항')),
#  ('샌프란시스코주립대학', ('샌프란시스코', '주립대학')),
#  ('샌프란시스코국제공항', ('샌프란시스코', '국제공항')),
#  ('미니애폴리스공항', ('미니애폴리스', '공항')),
#  ('샌프란시스코공항', ('샌프란시스코', '공항')),
#  ('주립종합대학교', ('주립', '종합대학교')),
#  ('학사관리사이트', ('학사', '관리', '사이트')),
#  ('지리적위치산타바바라', ('지리적위치', '산타바바라')),
#  ('그레이하운드버스타고', ('그레이하운드버스', '타고')),
#  ('버스위치정보시스템', ('버스위치', '정보', '시스템')),
#  ('시골버스터미널', ('시골', '버스터미널')),
#  ('미네아폴리스공항', ('미네아폴리스', '공항')),
#  ('캘리포니아기후라고', ('캘리포니아', '기후라고')),
#  ('교환학생준비', ('교환학생', '준비')),
#  ('세계명문대학', ('세계', '명문대학')),
#  ('국제교류프로그램', ('국제', '교류', '프로그램')),
#  ('설치되어있기때문', ('설치되어', '있기때문')),
#  ('경제경영수학전공', ('경제', '경영', '수학', '전공')),
#  ('비엔나개인적', ('비엔나', '개인적')),
#  ('루벤카톨릭대학', ('루벤', '카톨릭', '대학')),
#  ('네덜란드어지역', ('네덜란드어', '지역')),
#  ('종합단과대학', ('종합', '단과대학')),
#  ('밴쿠버국제공항', ('밴쿠버', '국제공항')),
#  ('경제학과학생', ('경제학과', '학생')),
#  ('지하철라인생활권', ('지하철', '라인', '생활권')),
#  ('산학협동프로그램', ('산학협동', '프로그램'))]

# %%
print((nouns['마약'])) #LR중요도였는데, counter library가서 순서 매겨야 함
#list 말고 숫자로밖에 순서도 ㄴ
#큐플, 숫자말고 레이블링. 
#tuple 
#generate wordcloud konlpy
# Out:
# NounScore_v1(frequency=5, score=0.8016826, known_r_ratio=1.0)

# %%
# %time df_tokens = df_column.apply(tokenizer.tokenize)
